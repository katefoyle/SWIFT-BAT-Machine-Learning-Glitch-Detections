# %% [markdown]
# This notebook generates detector plane images (dpis) of glitches caused by heat pipe-induced count rate increases in the SWIFT Burst Alert Telescope (BAT).
#
# Glitch events are pulled from GUANO and the event data is centered around the glitch using a 64ms time window. The DPI is constructed from the DETX and DETY coordinates of each detected event.
#
# Two resolutions are available, corresponding to two support vector machine models:
#
# "original" : full detector plane resolution (286 x 173)
#
# "lowRES" : binned resolution (~ 16 x 16)
#
# GUANO dump, if too large, will claim "out of index" and not run. ~ 1.5 years is the max i have found, needs adjusting to get desired amount of dpi saves.

# %%
resolution = "original"  # Choose between "original" or "lowRES"
total = 300  # Number of dpi files to save

# Enter beginning and ending dates for GUANO pull in "yyyy-mm-dd" format
begin = "2024-01-01"    # default is 2024-01-01 to 2025-01-01
end = "2024-06-01"

# %%
from swifttools.swift_too import Data, GUANO
from astropy.table import Table
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# ### helper functions

# %%
# gets 16ms bin of "bad time intervals" where glitch happens
def get_btis_for_glitches(evdata, tstart, tstop, tbin_size=.016):
    all_bad_twinds = []

    for start, stop in zip(tstart, tstop):
        bins = np.arange(start, stop + tbin_size / 2.0, tbin_size)
        ebl = evdata["ENERGY"] <= 25.0
        ebl2 = evdata["ENERGY"] > 50.0

        h = np.histogram(evdata["TIME"][ebl], bins=bins)[0]
        h2 = np.histogram(evdata["TIME"][ebl2], bins=bins)[0]
        
        stds = (h - np.mean(h)) / np.std(h)
        stds2 = (h2 - np.mean(h2)) / np.std(h2)
        
        bl_lowE_highSNR = stds > 10.0
        bl_highE_lowSNR = (stds / np.abs(stds2)) > 3
        bl_bad = bl_highE_lowSNR & bl_lowE_highSNR
    
        bad_twinds = []
        for i in range(np.sum(bl_bad)):
            t0 = bins[:-1][bl_bad][i]
            t1 = t0 + tbin_size
            bad_twind = (t0 - .024, t1 + .024)
            # 24ms before plus 16ms interval plus 24ms after for 64ms total
            bad_twinds.append(bad_twind)      

        if bad_twinds:
            all_bad_twinds.extend(bad_twinds)
    
    return all_bad_twinds


def det2dpi_sands_ebins(tab, ebins, weights=None):

    detxs_by_sand0 = np.arange(0, 286 - 15, 18)
    detxs_by_sand1 = detxs_by_sand0 + 15
    xbins = np.append(detxs_by_sand0, [detxs_by_sand1[-1]])

    detys_by_sand0 = np.arange(0, 173 - 7, 11)
    detys_by_sand1 = detys_by_sand0 + 7
    ybins = np.append(detys_by_sand0, [detys_by_sand1[-1]])
    
    sand_dpis = np.swapaxes(
        np.histogramdd([tab["DETX"], tab["DETY"], tab['ENERGY']], bins=[xbins, ybins, ebins], weights=weights)[
            0
        ],
        0,
        1,
    )

    return sand_dpis


def save_dpi(dpi, folder, prefix, saved, i, obsid):
    dpi_filename = f"{prefix}{saved + 1}_window_{i + 1}.npy"
    dpi_filepath = os.path.join(folder, dpi_filename)
    print(f"Saved DPI data for ObsID {obsid}, as {dpi_filename} in {folder} folder.")
    np.save(dpi_filepath, dpi)
    return dpi_filename

# %% [markdown]
# ### main

# %%
def NEWmain(resolution = "original", total = 300, begin="2024-01-01", end="2025-01-01"):   # default values
    assert resolution in ["original", "lowRES"], "Resolution must be 'original' or 'lowRES'"
    
    glitchdpi_folder = "GLITCHdpi" if resolution == "original" else "GLITCHdpi_lowRES"
    os.makedirs(glitchdpi_folder, exist_ok=True)
    
    scratchbase = os.path.expanduser("~/scratch")
    prefix = f"GLITCHdpi{'lowRES' if resolution == 'lowRES' else ''}_"

    existing_files = [f for f in os.listdir(glitchdpi_folder) if f.startswith(prefix) and f.endswith(".npy")]
    
    saved = len(existing_files)  # Start numbering from the next available file
    
    guano = GUANO(begin=begin, end=end)
    processedobsids = set()
    index = 0

    if saved == total:
        print(f"{saved} files already in {glitchdpi_folder}. Done.")
        return
    
    while saved < total:

        obsid = guano[index].obsnum
        
        print(f"\n\tIndex {index}")
        print(f"Glitch {saved}")
        print(f"Processing ObsID: {obsid}")

        obsid_folder = os.path.join(scratchbase, str(obsid), "bat", "event")
        obsname = os.path.join(scratchbase, str(obsid))
        fname = f"sw{obsid}bevshpo_uf.evt.gz"
        event_url = os.path.join(obsid_folder, fname)
                   
        
        if os.path.exists(event_url) or os.path.exists(obsname):
            print(f"Skipping ObsID {obsid} as event file already exists in directory.")
            processedobsids.add(obsid)
            index += 1
            continue
        
        os.makedirs(obsid_folder, exist_ok=True)

        try:
            print(f"Downloading {obsid} from GUANO.") 
            # Download event file from GUANO
            data = Data(obsid=obsid, bat=True, outdir=scratchbase, clobber=True)
            print(f"Downloaded event file to: {event_url}")
        except Exception as e:
            print(f"Error downloading event file for ObsID {obsid}: {e}. Skipping.")
            processedobsids.add(obsid)
            index += 1
            continue
        
                
        try:
            evtable = Table.read(event_url)
            event_GTI = Table.read(event_url, hdu='GTI')
        except Exception as e:
            print(f"Error reading event file for ObsID {obsid}: {e}. Skipping.")
            processedobsids.add(obsid) 
            index += 1
            continue

        tstart = event_GTI["START"].data
        tstop = event_GTI["STOP"].data

        glitch_twinds = get_btis_for_glitches(evtable, tstart, tstop)

        if not glitch_twinds:
            print(f"No glitches detected for ObsID {obsid}. Skipping.")
            processedobsids.add(obsid)
            index += 1
            continue


        # Process each glitch window
        for i, (t_min, t_max) in enumerate(glitch_twinds):
            bl = (evtable['TIME'] >= t_min) & (evtable['TIME'] <= t_max)
            binned_events = evtable[bl]

            if len(binned_events) == 0:
                continue

            if resolution == "original":
                xbins = np.arange(286 + 1) - 0.5
                ybins = np.arange(173 + 1) - 0.5                
                dpi = np.histogram2d(binned_events['DETX'], binned_events['DETY'], bins=[xbins, ybins])[0]
       
            else:
                ebins = [15, 50, 350]
                dpi = det2dpi_sands_ebins(binned_events, ebins)

            plt.close()
    
            if np.any(dpi):
                dpi_filename = save_dpi(dpi, glitchdpi_folder, prefix, saved, i, obsid)
                saved += 1
            
                if saved >= total:
                    print(f"Done. {total} GLITCH DPIs for {prefix} saved.")
                    return
    
            
        processedobsids.add(obsid)
        index += 1

# %%
NEWmain(resolution=resolution, total=total, begin=begin, end=end)
# Out:
# 	Index 0
# Glitch 277
# Processing ObsID: 00090372005
# Skipping ObsID 00090372005 as event file already exists in directory.
#
# 	Index 1
# Glitch 277
# Processing ObsID: 00016643004
# Skipping ObsID 00016643004 as event file already exists in directory.
#
# 	Index 2
# Glitch 277
# Processing ObsID: 00013509206
# Skipping ObsID 00013509206 as event file already exists in directory.
#
# 	Index 3
# Glitch 277
# Processing ObsID: 00030846092
# Skipping ObsID 00030846092 as event file already exists in directory.
#
# 	Index 4
# Glitch 277
# Processing ObsID: 00092436006
# Skipping ObsID 00092436006 as event file already exists in directory.
#
# 	Index 5
# Glitch 277
# Processing ObsID: 00016642008
# Skipping ObsID 00016642008 as event file already exists in directory.
#
# 	Index 6
# Glitch 277
# Processing ObsID: 00097137226
# Skipping ObsID 00097137226 as event file already exists in directory.
#
# 	Index 7
# Glitch 277
# Processing ObsID: 00080354007
# Skipping ObsID 00080354007 as event file already exists in directory.
#
# 	Index 8
# Glitch 277
# Processing ObsID: 00016648001
# Skipping ObsID 00016648001 as event file already exists in directory.
#
# 	Index 9
# Glitch 277
# Processing ObsID: 00080388004
# Skipping ObsID 00080388004 as event file already exists in directory.
#
# 	Index 10
# Glitch 277
# Processing ObsID: 00033012236
# Skipping ObsID 00033012236 as event file already exists in directory.
#
# 	Index 11
# Glitch 277
# Processing ObsID: 00033012236
# Skipping ObsID 00033012236 as event file already exists in directory.
#
# 	Index 12
# Glitch 277
# Processing ObsID: 00034134083
# Skipping ObsID 00034134083 as event file already exists in directory.
#
# 	Index 13
# Glitch 277
# Processing ObsID: 00097550021
# Skipping ObsID 00097550021 as event file already exists in directory.
#
# 	Index 14
# Glitch 277
# Processing ObsID: 00016646001
# Skipping ObsID 00016646001 as event file already exists in directory.
#
# 	Index 15
# Glitch 277
# Processing ObsID: 00016646001
# Skipping ObsID 00016646001 as event file already exists in directory.
#
# 	Index 16
# Glitch 277
# Processing ObsID: 00090372004
# Skipping ObsID 00090372004 as event file already exists in directory.
#
# 	Index 17
# Glitch 277
# Processing ObsID: 00021694004
# Skipping ObsID 00021694004 as event file already exists in directory.
#
# 	Index 18
# Glitch 277
# Processing ObsID: 00090372004
# Skipping ObsID 00090372004 as event file already exists in directory.
#
# 	Index 19
# Glitch 277
# Processing ObsID: 00016600023
# Skipping ObsID 00016600023 as event file already exists in directory.
#
# 	Index 20
# Glitch 277
# Processing ObsID: 00049502087
# Skipping ObsID 00049502087 as event file already exists in directory.
#
# 	Index 21
# Glitch 277
# Processing ObsID: 00030846088
# Skipping ObsID 00030846088 as event file already exists in directory.
#
# 	Index 22
# Glitch 277
# Processing ObsID: 01231488001
# Skipping ObsID 01231488001 as event file already exists in directory.
#
# 	Index 23
# Glitch 277
# Processing ObsID: 01231488001
# Skipping ObsID 01231488001 as event file already exists in directory.
#
# 	Index 24
# Glitch 277
# Processing ObsID: 00016637015
# Skipping ObsID 00016637015 as event file already exists in directory.
#
# 	Index 25
# Glitch 277
# Processing ObsID: 00092391008
# Skipping ObsID 00092391008 as event file already exists in directory.
#
# 	Index 26
# Glitch 277
# Processing ObsID: 00092391008
# Skipping ObsID 00092391008 as event file already exists in directory.
#
# 	Index 27
# Glitch 277
# Processing ObsID: 00016636019
# Skipping ObsID 00016636019 as event file already exists in directory.
#
# 	Index 28
# Glitch 277
# Processing ObsID: 00092391008
# Skipping ObsID 00092391008 as event file already exists in directory.
#
# 	Index 29
# Glitch 277
# Processing ObsID: 00075728019
# Skipping ObsID 00075728019 as event file already exists in directory.
#
# 	Index 30
# Glitch 277
# Processing ObsID: 00035344157
# Skipping ObsID 00035344157 as event file already exists in directory.
#
# 	Index 31
# Glitch 277
# Processing ObsID: 00030376173
# Skipping ObsID 00030376173 as event file already exists in directory.
#
# 	Index 32
# Glitch 277
# Processing ObsID: 00021694001
# Skipping ObsID 00021694001 as event file already exists in directory.
#
# 	Index 33
# Glitch 277
# Processing ObsID: 03111099073
# Skipping ObsID 03111099073 as event file already exists in directory.
#
# 	Index 34
# Glitch 277
# Processing ObsID: 00021694001
# Skipping ObsID 00021694001 as event file already exists in directory.
#
# 	Index 35
# Glitch 277
# Processing ObsID: 03111165075
# Skipping ObsID 03111165075 as event file already exists in directory.
#
# 	Index 36
# Glitch 277
# Processing ObsID: 00074074013
# Skipping ObsID 00074074013 as event file already exists in directory.
#
# 	Index 37
# Glitch 277
# Processing ObsID: 00097510001
# Skipping ObsID 00097510001 as event file already exists in directory.
#
# 	Index 38
# Glitch 277
# Processing ObsID: 00092583008
# Skipping ObsID 00092583008 as event file already exists in directory.
#
# 	Index 39
# Glitch 277
# Processing ObsID: 00016559011
# Skipping ObsID 00016559011 as event file already exists in directory.
#
# 	Index 40
# Glitch 277
# Processing ObsID: 00016217009
# Skipping ObsID 00016217009 as event file already exists in directory.
#
# 	Index 41
# Glitch 277
# Processing ObsID: 00030846084
# Skipping ObsID 00030846084 as event file already exists in directory.
#
# 	Index 42
# Glitch 277
# Processing ObsID: 00030846084
# Skipping ObsID 00030846084 as event file already exists in directory.
#
# 	Index 43
# Glitch 277
# Processing ObsID: 00016500024
# Skipping ObsID 00016500024 as event file already exists in directory.
#
# 	Index 44
# Glitch 277
# Processing ObsID: 00016500024
# Skipping ObsID 00016500024 as event file already exists in directory.
#
# 	Index 45
# Glitch 277
# Processing ObsID: 00016636018
# Skipping ObsID 00016636018 as event file already exists in directory.
#
# 	Index 46
# Glitch 277
# Processing ObsID: 00030846083
# Skipping ObsID 00030846083 as event file already exists in directory.
#
# 	Index 47
# Glitch 277
# Processing ObsID: 00097623003
# Skipping ObsID 00097623003 as event file already exists in directory.
#
# 	Index 48
# Glitch 277
# Processing ObsID: 00035020021
# Skipping ObsID 00035020021 as event file already exists in directory.
#
# 	Index 49
# Glitch 277
# Processing ObsID: 00096759003
# Skipping ObsID 00096759003 as event file already exists in directory.
#
# 	Index 50
# Glitch 277
# Processing ObsID: 00031976034
# Skipping ObsID 00031976034 as event file already exists in directory.
#
# 	Index 51
# Glitch 277
# Processing ObsID: 00096759003
# Skipping ObsID 00096759003 as event file already exists in directory.
#
# 	Index 52
# Glitch 277
# Processing ObsID: 00016600022
# Skipping ObsID 00016600022 as event file already exists in directory.
#
# 	Index 53
# Glitch 277
# Processing ObsID: 00080482005
# Skipping ObsID 00080482005 as event file already exists in directory.
#
# 	Index 54
# Glitch 277
# Processing ObsID: 00074969024
# Skipping ObsID 00074969024 as event file already exists in directory.
#
# 	Index 55
# Glitch 277
# Processing ObsID: 00097471003
# Skipping ObsID 00097471003 as event file already exists in directory.
#
# 	Index 56
# Glitch 277
# Processing ObsID: 00016430006
# Skipping ObsID 00016430006 as event file already exists in directory.
#
# 	Index 57
# Glitch 277
# Processing ObsID: 00016607002
# Skipping ObsID 00016607002 as event file already exists in directory.
#
# 	Index 58
# Glitch 277
# Processing ObsID: 00097767031
# Skipping ObsID 00097767031 as event file already exists in directory.
#
# 	Index 59
# Glitch 277
# Processing ObsID: 00097377010
# Skipping ObsID 00097377010 as event file already exists in directory.
#
# 	Index 60
# Glitch 277
# Processing ObsID: 00015411166
# Skipping ObsID 00015411166 as event file already exists in directory.
#
# 	Index 61
# Glitch 277
# Processing ObsID: 00015411166
# Skipping ObsID 00015411166 as event file already exists in directory.
#
# 	Index 62
# Glitch 277
# Processing ObsID: 00075742019
# Skipping ObsID 00075742019 as event file already exists in directory.
#
# 	Index 63
# Glitch 277
# Processing ObsID: 00097422004
# Skipping ObsID 00097422004 as event file already exists in directory.
#
# 	Index 64
# Glitch 277
# Processing ObsID: 00037354080
# Skipping ObsID 00037354080 as event file already exists in directory.
#
# 	Index 65
# Glitch 277
# Processing ObsID: 00097589001
# Skipping ObsID 00097589001 as event file already exists in directory.
#
# 	Index 66
# Glitch 277
# Processing ObsID: 00091620005
# Skipping ObsID 00091620005 as event file already exists in directory.
#
# 	Index 67
# Glitch 277
# Processing ObsID: 05000468003
# Skipping ObsID 05000468003 as event file already exists in directory.
#
# 	Index 68
# Glitch 277
# Processing ObsID: 00014350029
# Skipping ObsID 00014350029 as event file already exists in directory.
#
# 	Index 69
# Glitch 277
# Processing ObsID: 00030846076
# Skipping ObsID 00030846076 as event file already exists in directory.
#
# 	Index 70
# Glitch 277
# Processing ObsID: 00097491001
# Skipping ObsID 00097491001 as event file already exists in directory.
#
# 	Index 71
# Glitch 277
# Processing ObsID: 00092717004
# Skipping ObsID 00092717004 as event file already exists in directory.
#
# 	Index 72
# Glitch 277
# Processing ObsID: 00013509205
# Skipping ObsID 00013509205 as event file already exists in directory.
#
# 	Index 73
# Glitch 277
# Processing ObsID: 00097731011
# Skipping ObsID 00097731011 as event file already exists in directory.
#
# 	Index 74
# Glitch 277
# Processing ObsID: 00016639002
# Skipping ObsID 00016639002 as event file already exists in directory.
#
# 	Index 75
# Glitch 277
# Processing ObsID: 00097556029
# Skipping ObsID 00097556029 as event file already exists in directory.
#
# 	Index 76
# Glitch 277
# Processing ObsID: 00016100074
# Skipping ObsID 00016100074 as event file already exists in directory.
#
# 	Index 77
# Glitch 277
# Processing ObsID: 00097567001
# Skipping ObsID 00097567001 as event file already exists in directory.
#
# 	Index 78
# Glitch 277
# Processing ObsID: 00013544244
# Skipping ObsID 00013544244 as event file already exists in directory.
#
# 	Index 79
# Glitch 277
# Processing ObsID: 00016634010
# Skipping ObsID 00016634010 as event file already exists in directory.
#
# 	Index 80
# Glitch 277
# Processing ObsID: 00097487003
# Skipping ObsID 00097487003 as event file already exists in directory.
#
# 	Index 81
# Glitch 277
# Processing ObsID: 00097487003
# Skipping ObsID 00097487003 as event file already exists in directory.
#
# 	Index 82
# Glitch 277
# Processing ObsID: 00016100074
# Skipping ObsID 00016100074 as event file already exists in directory.
#
# 	Index 83
# Glitch 277
# Processing ObsID: 00016637010
# Skipping ObsID 00016637010 as event file already exists in directory.
#
# 	Index 84
# Glitch 277
# Processing ObsID: 00091620005
# Skipping ObsID 00091620005 as event file already exists in directory.
#
# 	Index 85
# Glitch 277
# Processing ObsID: 00075591037
# Skipping ObsID 00075591037 as event file already exists in directory.
#
# 	Index 86
# Glitch 277
# Processing ObsID: 01227767018
# Skipping ObsID 01227767018 as event file already exists in directory.
#
# 	Index 87
# Glitch 277
# Processing ObsID: 00015858082
# Skipping ObsID 00015858082 as event file already exists in directory.
#
# 	Index 88
# Glitch 277
# Processing ObsID: 00016564007
# Skipping ObsID 00016564007 as event file already exists in directory.
#
# 	Index 89
# Glitch 277
# Processing ObsID: 00080354002
# Skipping ObsID 00080354002 as event file already exists in directory.
#
# 	Index 90
# Glitch 277
# Processing ObsID: 00016476020
# Skipping ObsID 00016476020 as event file already exists in directory.
#
# 	Index 91
# Glitch 277
# Processing ObsID: 01227767017
# Skipping ObsID 01227767017 as event file already exists in directory.
#
# 	Index 92
# Glitch 277
# Processing ObsID: 00097403003
# Skipping ObsID 00097403003 as event file already exists in directory.
#
# 	Index 93
# Glitch 277
# Processing ObsID: 00015425036
# Skipping ObsID 00015425036 as event file already exists in directory.
#
# 	Index 94
# Glitch 277
# Processing ObsID: 00097564030
# Skipping ObsID 00097564030 as event file already exists in directory.
#
# 	Index 95
# Glitch 277
# Processing ObsID: 00016631008
# Skipping ObsID 00016631008 as event file already exists in directory.
#
# 	Index 96
# Glitch 277
# Processing ObsID: 00097302051
# Skipping ObsID 00097302051 as event file already exists in directory.
#
# 	Index 97
# Glitch 277
# Processing ObsID: 00015870018
# Skipping ObsID 00015870018 as event file already exists in directory.
#
# 	Index 98
# Glitch 277
# Processing ObsID: 00038995016
# Skipping ObsID 00038995016 as event file already exists in directory.
#
# 	Index 99
# Glitch 277
# Processing ObsID: 00016433003
# Skipping ObsID 00016433003 as event file already exists in directory.
#
# 	Index 100
# Glitch 277
# Processing ObsID: 00097766006
# Skipping ObsID 00097766006 as event file already exists in directory.
#
# 	Index 101
# Glitch 277
# Processing ObsID: 00075560006
# Skipping ObsID 00075560006 as event file already exists in directory.
#
# 	Index 102
# Glitch 277
# Processing ObsID: 00016638013
# Skipping ObsID 00016638013 as event file already exists in directory.
#
# 	Index 103
# Glitch 277
# Processing ObsID: 00016601064
# Skipping ObsID 00016601064 as event file already exists in directory.
#
# 	Index 104
# Glitch 277
# Processing ObsID: 00037354079
# Skipping ObsID 00037354079 as event file already exists in directory.
#
# 	Index 105
# Glitch 277
# Processing ObsID: 00010976022
# Skipping ObsID 00010976022 as event file already exists in directory.
#
# 	Index 106
# Glitch 277
# Processing ObsID: 00015007035
# Skipping ObsID 00015007035 as event file already exists in directory.
#
# 	Index 107
# Glitch 277
# Processing ObsID: 00010377082
# Skipping ObsID 00010377082 as event file already exists in directory.
#
# 	Index 108
# Glitch 277
# Processing ObsID: 00010695023
# Skipping ObsID 00010695023 as event file already exists in directory.
#
# 	Index 109
# Glitch 277
# Processing ObsID: 00097712009
# Skipping ObsID 00097712009 as event file already exists in directory.
#
# 	Index 110
# Glitch 277
# Processing ObsID: 00010377082
# Skipping ObsID 00010377082 as event file already exists in directory.
#
# 	Index 111
# Glitch 277
# Processing ObsID: 00097444004
# Skipping ObsID 00097444004 as event file already exists in directory.
#
# 	Index 112
# Glitch 277
# Processing ObsID: 00074907040
# Skipping ObsID 00074907040 as event file already exists in directory.
#
# 	Index 113
# Glitch 277
# Processing ObsID: 00016606008
# Skipping ObsID 00016606008 as event file already exists in directory.
#
# 	Index 114
# Glitch 277
# Processing ObsID: 00090536002
# Skipping ObsID 00090536002 as event file already exists in directory.
#
# 	Index 115
# Glitch 277
# Processing ObsID: 00097649003
# Skipping ObsID 00097649003 as event file already exists in directory.
#
# 	Index 116
# Glitch 277
# Processing ObsID: 00097649003
# Skipping ObsID 00097649003 as event file already exists in directory.
#
# 	Index 117
# Glitch 277
# Processing ObsID: 00032249165
# Skipping ObsID 00032249165 as event file already exists in directory.
#
# 	Index 118
# Glitch 277
# Processing ObsID: 00090536002
# Skipping ObsID 00090536002 as event file already exists in directory.
#
# 	Index 119
# Glitch 277
# Processing ObsID: 00075730025
# Skipping ObsID 00075730025 as event file already exists in directory.
#
# 	Index 120
# Glitch 277
# Processing ObsID: 00014052229
# Skipping ObsID 00014052229 as event file already exists in directory.
#
# 	Index 121
# Glitch 277
# Processing ObsID: 00097384002
# Skipping ObsID 00097384002 as event file already exists in directory.
#
# 	Index 122
# Glitch 277
# Processing ObsID: 00035462238
# Skipping ObsID 00035462238 as event file already exists in directory.
#
# 	Index 123
# Glitch 277
# Processing ObsID: 00038995015
# Skipping ObsID 00038995015 as event file already exists in directory.
#
# 	Index 124
# Glitch 277
# Processing ObsID: 00038995015
# Skipping ObsID 00038995015 as event file already exists in directory.
#
# 	Index 125
# Glitch 277
# Processing ObsID: 00016436040
# Skipping ObsID 00016436040 as event file already exists in directory.
#
# 	Index 126
# Glitch 277
# Processing ObsID: 00016500022
# Skipping ObsID 00016500022 as event file already exists in directory.
#
# 	Index 127
# Glitch 277
# Processing ObsID: 00076365011
# Skipping ObsID 00076365011 as event file already exists in directory.
#
# 	Index 128
# Glitch 277
# Processing ObsID: 00076365011
# Skipping ObsID 00076365011 as event file already exists in directory.
#
# 	Index 129
# Glitch 277
# Processing ObsID: 00014350027
# Skipping ObsID 00014350027 as event file already exists in directory.
#
# 	Index 130
# Glitch 277
# Processing ObsID: 00014350027
# Skipping ObsID 00014350027 as event file already exists in directory.
#
# 	Index 131
# Glitch 277
# Processing ObsID: 00080384002
# Skipping ObsID 00080384002 as event file already exists in directory.
#
# 	Index 132
# Glitch 277
# Processing ObsID: 00092720005
# Skipping ObsID 00092720005 as event file already exists in directory.
#
# 	Index 133
# Glitch 277
# Processing ObsID: 00097556025
# Skipping ObsID 00097556025 as event file already exists in directory.
#
# 	Index 134
# Glitch 277
# Processing ObsID: 00016601063
# Skipping ObsID 00016601063 as event file already exists in directory.
#
# 	Index 135
# Glitch 277
# Processing ObsID: 00097728003
# Skipping ObsID 00097728003 as event file already exists in directory.
#
# 	Index 136
# Glitch 277
# Processing ObsID: 01228973000
# Skipping ObsID 01228973000 as event file already exists in directory.
#
# 	Index 137
# Glitch 277
# Processing ObsID: 03111922007
# Skipping ObsID 03111922007 as event file already exists in directory.
#
# 	Index 138
# Glitch 277
# Processing ObsID: 00016100073
# Skipping ObsID 00016100073 as event file already exists in directory.
#
# 	Index 139
# Glitch 277
# Processing ObsID: 01228797002
# Skipping ObsID 01228797002 as event file already exists in directory.
#
# 	Index 140
# Glitch 277
# Processing ObsID: 00016636009
# Skipping ObsID 00016636009 as event file already exists in directory.
#
# 	Index 141
# Glitch 277
# Processing ObsID: 00092720004
# Skipping ObsID 00092720004 as event file already exists in directory.
#
# 	Index 142
# Glitch 277
# Processing ObsID: 00016638006
# Skipping ObsID 00016638006 as event file already exists in directory.
#
# 	Index 143
# Glitch 277
# Processing ObsID: 00016638006
# Skipping ObsID 00016638006 as event file already exists in directory.
#
# 	Index 144
# Glitch 277
# Processing ObsID: 00091277003
# Skipping ObsID 00091277003 as event file already exists in directory.
#
# 	Index 145
# Glitch 277
# Processing ObsID: 00091277003
# Skipping ObsID 00091277003 as event file already exists in directory.
#
# 	Index 146
# Glitch 277
# Processing ObsID: 00092583002
# Skipping ObsID 00092583002 as event file already exists in directory.
#
# 	Index 147
# Glitch 277
# Processing ObsID: 00015260068
# Skipping ObsID 00015260068 as event file already exists in directory.
#
# 	Index 148
# Glitch 277
# Processing ObsID: 00092711002
# Skipping ObsID 00092711002 as event file already exists in directory.
#
# 	Index 149
# Glitch 277
# Processing ObsID: 00092711002
# Skipping ObsID 00092711002 as event file already exists in directory.
#
# 	Index 150
# Glitch 277
# Processing ObsID: 00092720003
# Skipping ObsID 00092720003 as event file already exists in directory.
#
# 	Index 151
# Glitch 277
# Processing ObsID: 00097778002
# Skipping ObsID 00097778002 as event file already exists in directory.
#
# 	Index 152
# Glitch 277
# Processing ObsID: 00030846053
# Skipping ObsID 00030846053 as event file already exists in directory.
#
# 	Index 153
# Glitch 277
# Processing ObsID: 00030846053
# Skipping ObsID 00030846053 as event file already exists in directory.
#
# 	Index 154
# Glitch 277
# Processing ObsID: 00016631004
# Skipping ObsID 00016631004 as event file already exists in directory.
#
# 	Index 155
# Glitch 277
# Processing ObsID: 00091620002
# Skipping ObsID 00091620002 as event file already exists in directory.
#
# 	Index 156
# Glitch 277
# Processing ObsID: 00016631004
# Skipping ObsID 00016631004 as event file already exists in directory.
#
# 	Index 157
# Glitch 277
# Processing ObsID: 00031731046
# Skipping ObsID 00031731046 as event file already exists in directory.
#
# 	Index 158
# Glitch 277
# Processing ObsID: 00016609006
# Skipping ObsID 00016609006 as event file already exists in directory.
#
# 	Index 159
# Glitch 277
# Processing ObsID: 00015858077
# Skipping ObsID 00015858077 as event file already exists in directory.
#
# 	Index 160
# Glitch 277
# Processing ObsID: 00016638002
# Skipping ObsID 00016638002 as event file already exists in directory.
#
# 	Index 161
# Glitch 277
# Processing ObsID: 03111087073
# Skipping ObsID 03111087073 as event file already exists in directory.
#
# 	Index 162
# Glitch 277
# Processing ObsID: 03111087073
# Skipping ObsID 03111087073 as event file already exists in directory.
#
# 	Index 163
# Glitch 277
# Processing ObsID: 03111087073
# Skipping ObsID 03111087073 as event file already exists in directory.
#
# 	Index 164
# Glitch 277
# Processing ObsID: 00097422002
# Skipping ObsID 00097422002 as event file already exists in directory.
#
# 	Index 165
# Glitch 277
# Processing ObsID: 01228504000
# Skipping ObsID 01228504000 as event file already exists in directory.
#
# 	Index 166
# Glitch 277
# Processing ObsID: 00034134082
# Skipping ObsID 00034134082 as event file already exists in directory.
#
# 	Index 167
# Glitch 277
# Processing ObsID: 00097302040
# Skipping ObsID 00097302040 as event file already exists in directory.
#
# 	Index 168
# Glitch 277
# Processing ObsID: 00097302040
# Skipping ObsID 00097302040 as event file already exists in directory.
#
# 	Index 169
# Glitch 277
# Processing ObsID: 00016178037
# Skipping ObsID 00016178037 as event file already exists in directory.
#
# 	Index 170
# Glitch 277
# Processing ObsID: 00032671096
# Skipping ObsID 00032671096 as event file already exists in directory.
#
# 	Index 171
# Glitch 277
# Processing ObsID: 03112528143
# Skipping ObsID 03112528143 as event file already exists in directory.
#
# 	Index 172
# Glitch 277
# Processing ObsID: 00016634004
# Skipping ObsID 00016634004 as event file already exists in directory.
#
# 	Index 173
# Glitch 277
# Processing ObsID: 00021685001
# Skipping ObsID 00021685001 as event file already exists in directory.
#
# 	Index 174
# Glitch 277
# Processing ObsID: 00097509001
# Skipping ObsID 00097509001 as event file already exists in directory.
#
# 	Index 175
# Glitch 277
# Processing ObsID: 03112530145
# Skipping ObsID 03112530145 as event file already exists in directory.
#
# 	Index 176
# Glitch 277
# Processing ObsID: 00021687001
# Skipping ObsID 00021687001 as event file already exists in directory.
#
# 	Index 177
# Glitch 277
# Processing ObsID: 00037354076
# Skipping ObsID 00037354076 as event file already exists in directory.
#
# 	Index 178
# Glitch 277
# Processing ObsID: 00016638001
# Skipping ObsID 00016638001 as event file already exists in directory.
#
# 	Index 179
# Glitch 277
# Processing ObsID: 00097720001
# Skipping ObsID 00097720001 as event file already exists in directory.
#
# 	Index 180
# Glitch 277
# Processing ObsID: 00097379004
# Skipping ObsID 00097379004 as event file already exists in directory.
#
# 	Index 181
# Glitch 277
# Processing ObsID: 03112526085
# Skipping ObsID 03112526085 as event file already exists in directory.
#
# 	Index 182
# Glitch 277
# Processing ObsID: 00016637009
# Skipping ObsID 00016637009 as event file already exists in directory.
#
# 	Index 183
# Glitch 277
# Processing ObsID: 00097723003
# Skipping ObsID 00097723003 as event file already exists in directory.
#
# 	Index 184
# Glitch 277
# Processing ObsID: 00030846049
# Skipping ObsID 00030846049 as event file already exists in directory.
#
# 	Index 185
# Glitch 277
# Processing ObsID: 00016637008
# Skipping ObsID 00016637008 as event file already exists in directory.
#
# 	Index 186
# Glitch 277
# Processing ObsID: 00016629008
# Skipping ObsID 00016629008 as event file already exists in directory.
#
# 	Index 187
# Glitch 277
# Processing ObsID: 00016637008
# Skipping ObsID 00016637008 as event file already exists in directory.
#
# 	Index 188
# Glitch 277
# Processing ObsID: 01227767003
# Skipping ObsID 01227767003 as event file already exists in directory.
#
# 	Index 189
# Glitch 277
# Processing ObsID: 01227767003
# Skipping ObsID 01227767003 as event file already exists in directory.
#
# 	Index 190
# Glitch 277
# Processing ObsID: 01227767003
# Skipping ObsID 01227767003 as event file already exists in directory.
#
# 	Index 191
# Glitch 277
# Processing ObsID: 03112530145
# Skipping ObsID 03112530145 as event file already exists in directory.
#
# 	Index 192
# Glitch 277
# Processing ObsID: 00031540221
# Skipping ObsID 00031540221 as event file already exists in directory.
#
# 	Index 193
# Glitch 277
# Processing ObsID: 00097779003
# Skipping ObsID 00097779003 as event file already exists in directory.
#
# 	Index 194
# Glitch 277
# Processing ObsID: 00016630001
# Skipping ObsID 00016630001 as event file already exists in directory.
#
# 	Index 195
# Glitch 277
# Processing ObsID: 00046371022
# Skipping ObsID 00046371022 as event file already exists in directory.
#
# 	Index 196
# Glitch 277
# Processing ObsID: 01227767003
# Skipping ObsID 01227767003 as event file already exists in directory.
#
# 	Index 197
# Glitch 277
# Processing ObsID: 00016634003
# Skipping ObsID 00016634003 as event file already exists in directory.
#
# 	Index 198
# Glitch 277
# Processing ObsID: 01227767003
# Skipping ObsID 01227767003 as event file already exists in directory.
#
# 	Index 199
# Glitch 277
# Processing ObsID: 00016637007
# Skipping ObsID 00016637007 as event file already exists in directory.
#
# 	Index 200
# Glitch 277
# Processing ObsID: 00010976016
# Skipping ObsID 00010976016 as event file already exists in directory.
#
# 	Index 201
# Glitch 277
# Processing ObsID: 00016560025
# Skipping ObsID 00016560025 as event file already exists in directory.
#
# 	Index 202
# Glitch 277
# Processing ObsID: 00016601055
# Skipping ObsID 00016601055 as event file already exists in directory.
#
# 	Index 203
# Glitch 277
# Processing ObsID: 00030846047
# Skipping ObsID 00030846047 as event file already exists in directory.
#
# 	Index 204
# Glitch 277
# Processing ObsID: 03112530145
# Skipping ObsID 03112530145 as event file already exists in directory.
#
# 	Index 205
# Glitch 277
# Processing ObsID: 01227767002
# Skipping ObsID 01227767002 as event file already exists in directory.
#
# 	Index 206
# Glitch 277
# Processing ObsID: 00016585012
# Skipping ObsID 00016585012 as event file already exists in directory.
#
# 	Index 207
# Glitch 277
# Processing ObsID: 00097137203
# Skipping ObsID 00097137203 as event file already exists in directory.
#
# 	Index 208
# Glitch 277
# Processing ObsID: 00035482003
# Skipping ObsID 00035482003 as event file already exists in directory.
#
# 	Index 209
# Glitch 277
# Processing ObsID: 00016629007
# Skipping ObsID 00016629007 as event file already exists in directory.
#
# 	Index 210
# Glitch 277
# Processing ObsID: 01227869000
# Skipping ObsID 01227869000 as event file already exists in directory.
#
# 	Index 211
# Glitch 277
# Processing ObsID: 01227868000
# Skipping ObsID 01227868000 as event file already exists in directory.
#
# 	Index 212
# Glitch 277
# Processing ObsID: 00036557033
# Skipping ObsID 00036557033 as event file already exists in directory.
#
# 	Index 213
# Glitch 277
# Processing ObsID: 01227767002
# Skipping ObsID 01227767002 as event file already exists in directory.
#
# 	Index 214
# Glitch 277
# Processing ObsID: 00035344146
# Skipping ObsID 00035344146 as event file already exists in directory.
#
# 	Index 215
# Glitch 277
# Processing ObsID: 00035344146
# Skipping ObsID 00035344146 as event file already exists in directory.
#
# 	Index 216
# Glitch 277
# Processing ObsID: 03112530145
# Skipping ObsID 03112530145 as event file already exists in directory.
#
# 	Index 217
# Glitch 277
# Processing ObsID: 01227767002
# Skipping ObsID 01227767002 as event file already exists in directory.
#
# 	Index 218
# Glitch 277
# Processing ObsID: 00015411158
# Skipping ObsID 00015411158 as event file already exists in directory.
#
# 	Index 219
# Glitch 277
# Processing ObsID: 00014012124
# Skipping ObsID 00014012124 as event file already exists in directory.
#
# 	Index 220
# Glitch 277
# Processing ObsID: 01227767002
# Skipping ObsID 01227767002 as event file already exists in directory.
#
# 	Index 221
# Glitch 277
# Processing ObsID: 00097401006
# Skipping ObsID 00097401006 as event file already exists in directory.
#
# 	Index 222
# Glitch 277
# Processing ObsID: 00016627001
# Skipping ObsID 00016627001 as event file already exists in directory.
#
# 	Index 223
# Glitch 277
# Processing ObsID: 03112530143
# Skipping ObsID 03112530143 as event file already exists in directory.
#
# 	Index 224
# Glitch 277
# Processing ObsID: 01227767002
# Skipping ObsID 01227767002 as event file already exists in directory.
#
# 	Index 225
# Glitch 277
# Processing ObsID: 01227767002
# Skipping ObsID 01227767002 as event file already exists in directory.
#
# 	Index 226
# Glitch 277
# Processing ObsID: 00013906117
# Skipping ObsID 00013906117 as event file already exists in directory.
#
# 	Index 227
# Glitch 277
# Processing ObsID: 00046502006
# Skipping ObsID 00046502006 as event file already exists in directory.
#
# 	Index 228
# Glitch 277
# Processing ObsID: 00097723002
# Skipping ObsID 00097723002 as event file already exists in directory.
#
# 	Index 229
# Glitch 277
# Processing ObsID: 00097723002
# Skipping ObsID 00097723002 as event file already exists in directory.
#
# 	Index 230
# Glitch 277
# Processing ObsID: 00097740002
# Skipping ObsID 00097740002 as event file already exists in directory.
#
# 	Index 231
# Glitch 277
# Processing ObsID: 00016627001
# Skipping ObsID 00016627001 as event file already exists in directory.
#
# 	Index 232
# Glitch 277
# Processing ObsID: 00016627001
# Skipping ObsID 00016627001 as event file already exists in directory.
#
# 	Index 233
# Glitch 277
# Processing ObsID: 00016627001
# Skipping ObsID 00016627001 as event file already exists in directory.
#
# 	Index 234
# Glitch 277
# Processing ObsID: 00031976033
# Skipping ObsID 00031976033 as event file already exists in directory.
#
# 	Index 235
# Glitch 277
# Processing ObsID: 00031976033
# Skipping ObsID 00031976033 as event file already exists in directory.
#
# 	Index 236
# Glitch 277
# Processing ObsID: 00097740002
# Skipping ObsID 00097740002 as event file already exists in directory.
#
# 	Index 237
# Glitch 277
# Processing ObsID: 00097766005
# Skipping ObsID 00097766005 as event file already exists in directory.
#
# 	Index 238
# Glitch 277
# Processing ObsID: 01227702000
# Skipping ObsID 01227702000 as event file already exists in directory.
#
# 	Index 239
# Glitch 277
# Processing ObsID: 00097423001
# Skipping ObsID 00097423001 as event file already exists in directory.
#
# 	Index 240
# Glitch 277
# Processing ObsID: 00010976015
# Skipping ObsID 00010976015 as event file already exists in directory.
#
# 	Index 241
# Glitch 277
# Processing ObsID: 00097564022
# Skipping ObsID 00097564022 as event file already exists in directory.
#
# 	Index 242
# Glitch 277
# Processing ObsID: 00045942015
# Skipping ObsID 00045942015 as event file already exists in directory.
#
# 	Index 243
# Glitch 277
# Processing ObsID: 00045942015
# Skipping ObsID 00045942015 as event file already exists in directory.
#
# 	Index 244
# Glitch 277
# Processing ObsID: 03112530143
# Skipping ObsID 03112530143 as event file already exists in directory.
#
# 	Index 245
# Glitch 277
# Processing ObsID: 00031731044
# Skipping ObsID 00031731044 as event file already exists in directory.
#
# 	Index 246
# Glitch 277
# Processing ObsID: 00097377007
# Skipping ObsID 00097377007 as event file already exists in directory.
#
# 	Index 247
# Glitch 277
# Processing ObsID: 00097377007
# Skipping ObsID 00097377007 as event file already exists in directory.
#
# 	Index 248
# Glitch 277
# Processing ObsID: 00097377007
# Skipping ObsID 00097377007 as event file already exists in directory.
#
# 	Index 249
# Glitch 277
# Processing ObsID: 00097377007
# Skipping ObsID 00097377007 as event file already exists in directory.
#
# 	Index 250
# Glitch 277
# Processing ObsID: 00097421001
# Skipping ObsID 00097421001 as event file already exists in directory.
#
# 	Index 251
# Glitch 277
# Processing ObsID: 00016431007
# Skipping ObsID 00016431007 as event file already exists in directory.
#
# 	Index 252
# Glitch 277
# Processing ObsID: 00016431007
# Skipping ObsID 00016431007 as event file already exists in directory.
#
# 	Index 253
# Glitch 277
# Processing ObsID: 00016627001
# Skipping ObsID 00016627001 as event file already exists in directory.
#
# 	Index 254
# Glitch 277
# Processing ObsID: 00016637002
# Skipping ObsID 00016637002 as event file already exists in directory.
#
# 	Index 255
# Glitch 277
# Processing ObsID: 00016631002
# Skipping ObsID 00016631002 as event file already exists in directory.
#
# 	Index 256
# Glitch 277
# Processing ObsID: 00074189043
# Skipping ObsID 00074189043 as event file already exists in directory.
#
# 	Index 257
# Glitch 277
# Processing ObsID: 00074189043
# Skipping ObsID 00074189043 as event file already exists in directory.
#
# 	Index 258
# Glitch 277
# Processing ObsID: 00016637002
# Skipping ObsID 00016637002 as event file already exists in directory.
#
# 	Index 259
# Glitch 277
# Processing ObsID: 00016637002
# Skipping ObsID 00016637002 as event file already exists in directory.
#
# 	Index 260
# Glitch 277
# Processing ObsID: 00016629006
# Skipping ObsID 00016629006 as event file already exists in directory.
#
# 	Index 261
# Glitch 277
# Processing ObsID: 00016629006
# Skipping ObsID 00016629006 as event file already exists in directory.
#
# 	Index 262
# Glitch 277
# Processing ObsID: 00036557032
# Skipping ObsID 00036557032 as event file already exists in directory.
#
# 	Index 263
# Glitch 277
# Processing ObsID: 01227618000
# Skipping ObsID 01227618000 as event file already exists in directory.
#
# 	Index 264
# Glitch 277
# Processing ObsID: 00097423001
# Skipping ObsID 00097423001 as event file already exists in directory.
#
# 	Index 265
# Glitch 277
# Processing ObsID: 00097376001
# Skipping ObsID 00097376001 as event file already exists in directory.
#
# 	Index 266
# Glitch 277
# Processing ObsID: 00097201008
# Skipping ObsID 00097201008 as event file already exists in directory.
#
# 	Index 267
# Glitch 277
# Processing ObsID: 00016446038
# Skipping ObsID 00016446038 as event file already exists in directory.
#
# 	Index 268
# Glitch 277
# Processing ObsID: 00097423001
# Skipping ObsID 00097423001 as event file already exists in directory.
#
# 	Index 269
# Glitch 277
# Processing ObsID: 00097423001
# Skipping ObsID 00097423001 as event file already exists in directory.
#
# 	Index 270
# Glitch 277
# Processing ObsID: 03112530143
# Skipping ObsID 03112530143 as event file already exists in directory.
#
# 	Index 271
# Glitch 277
# Processing ObsID: 00031976033
# Skipping ObsID 00031976033 as event file already exists in directory.
#
# 	Index 272
# Glitch 277
# Processing ObsID: 00031540219
# Skipping ObsID 00031540219 as event file already exists in directory.
#
# 	Index 273
# Glitch 277
# Processing ObsID: 03112530143
# Skipping ObsID 03112530143 as event file already exists in directory.
#
# 	Index 274
# Glitch 277
# Processing ObsID: 01227588000
# Skipping ObsID 01227588000 as event file already exists in directory.
#
# 	Index 275
# Glitch 277
# Processing ObsID: 00015026077
# Skipping ObsID 00015026077 as event file already exists in directory.
#
# 	Index 276
# Glitch 277
# Processing ObsID: 00016637001
# Skipping ObsID 00016637001 as event file already exists in directory.
#
# 	Index 277
# Glitch 277
# Processing ObsID: 03112530143
# Skipping ObsID 03112530143 as event file already exists in directory.
#
# 	Index 278
# Glitch 277
# Processing ObsID: 03112116023
# Skipping ObsID 03112116023 as event file already exists in directory.
#
# 	Index 279
# Glitch 277
# Processing ObsID: 00016637001
# Skipping ObsID 00016637001 as event file already exists in directory.
#
# 	Index 280
# Glitch 277
# Processing ObsID: 00030846044
# Skipping ObsID 00030846044 as event file already exists in directory.
#
# 	Index 281
# Glitch 277
# Processing ObsID: 00015026077
# Skipping ObsID 00015026077 as event file already exists in directory.
#
# 	Index 282
# Glitch 277
# Processing ObsID: 00014350022
# Skipping ObsID 00014350022 as event file already exists in directory.
#
# 	Index 283
# Glitch 277
# Processing ObsID: 00035011103
# Skipping ObsID 00035011103 as event file already exists in directory.
#
# 	Index 284
# Glitch 277
# Processing ObsID: 00016500019
# Skipping ObsID 00016500019 as event file already exists in directory.
#
# 	Index 285
# Glitch 277
# Processing ObsID: 00016500019
# Skipping ObsID 00016500019 as event file already exists in directory.
#
# 	Index 286
# Glitch 277
# Processing ObsID: 00097524005
# Skipping ObsID 00097524005 as event file already exists in directory.
#
# 	Index 287
# Glitch 277
# Processing ObsID: 03112530143
# Skipping ObsID 03112530143 as event file already exists in directory.
#
# 	Index 288
# Glitch 277
# Processing ObsID: 00013509202
# Skipping ObsID 00013509202 as event file already exists in directory.
#
# 	Index 289
# Glitch 277
# Processing ObsID: 00015858076
# Skipping ObsID 00015858076 as event file already exists in directory.
#
# 	Index 290
# Glitch 277
# Processing ObsID: 00016628001
# Skipping ObsID 00016628001 as event file already exists in directory.
#
# 	Index 291
# Glitch 277
# Processing ObsID: 00097525004
# Skipping ObsID 00097525004 as event file already exists in directory.
#
# 	Index 292
# Glitch 277
# Processing ObsID: 00016631001
# Skipping ObsID 00016631001 as event file already exists in directory.
#
# 	Index 293
# Glitch 277
# Processing ObsID: 03112530141
# Skipping ObsID 03112530141 as event file already exists in directory.
#
# 	Index 294
# Glitch 277
# Processing ObsID: 00016624004
# Skipping ObsID 00016624004 as event file already exists in directory.
#
# 	Index 295
# Glitch 277
# Processing ObsID: 03112528139
# Skipping ObsID 03112528139 as event file already exists in directory.
#
# 	Index 296
# Glitch 277
# Processing ObsID: 03112528139
# Skipping ObsID 03112528139 as event file already exists in directory.
#
# 	Index 297
# Glitch 277
# Processing ObsID: 00016628001
# Skipping ObsID 00016628001 as event file already exists in directory.
#
# 	Index 298
# Glitch 277
# Processing ObsID: 03112567015
# Skipping ObsID 03112567015 as event file already exists in directory.
#
# 	Index 299
# Glitch 277
# Processing ObsID: 00016552022
# Skipping ObsID 00016552022 as event file already exists in directory.
#
# 	Index 300
# Glitch 277
# Processing ObsID: 00097394001
# Skipping ObsID 00097394001 as event file already exists in directory.
#
# 	Index 301
# Glitch 277
# Processing ObsID: 00097394001
# Skipping ObsID 00097394001 as event file already exists in directory.
#
# 	Index 302
# Glitch 277
# Processing ObsID: 00074174046
# Skipping ObsID 00074174046 as event file already exists in directory.
#
# 	Index 303
# Glitch 277
# Processing ObsID: 00016629004
# Skipping ObsID 00016629004 as event file already exists in directory.
#
# 	Index 304
# Glitch 277
# Processing ObsID: 03112530141
# Skipping ObsID 03112530141 as event file already exists in directory.
#
# 	Index 305
# Glitch 277
# Processing ObsID: 00033300058
# Skipping ObsID 00033300058 as event file already exists in directory.
#
# 	Index 306
# Glitch 277
# Processing ObsID: 00033300058
# Skipping ObsID 00033300058 as event file already exists in directory.
#
# 	Index 307
# Glitch 277
# Processing ObsID: 00037354075
# Skipping ObsID 00037354075 as event file already exists in directory.
#
# 	Index 308
# Glitch 277
# Processing ObsID: 03112532248
# Skipping ObsID 03112532248 as event file already exists in directory.
#
# 	Index 309
# Glitch 277
# Processing ObsID: 00037059006
# Skipping ObsID 00037059006 as event file already exists in directory.
#
# 	Index 310
# Glitch 277
# Processing ObsID: 00016506026
# Skipping ObsID 00016506026 as event file already exists in directory.
#
# 	Index 311
# Glitch 277
# Processing ObsID: 03112099006
# Skipping ObsID 03112099006 as event file already exists in directory.
#
# 	Index 312
# Glitch 277
# Processing ObsID: 00016564006
# Skipping ObsID 00016564006 as event file already exists in directory.
#
# 	Index 313
# Glitch 277
# Processing ObsID: 00097486002
# Skipping ObsID 00097486002 as event file already exists in directory.
#
# 	Index 314
# Glitch 277
# Processing ObsID: 00035344144
# Skipping ObsID 00035344144 as event file already exists in directory.
#
# 	Index 315
# Glitch 277
# Processing ObsID: 00035344144
# Skipping ObsID 00035344144 as event file already exists in directory.
#
# 	Index 316
# Glitch 277
# Processing ObsID: 00035344144
# Skipping ObsID 00035344144 as event file already exists in directory.
#
# 	Index 317
# Glitch 277
# Processing ObsID: 03112105057
# Skipping ObsID 03112105057 as event file already exists in directory.
#
# 	Index 318
# Glitch 277
# Processing ObsID: 00097379003
# Skipping ObsID 00097379003 as event file already exists in directory.
#
# 	Index 319
# Glitch 277
# Processing ObsID: 00036870004
# Skipping ObsID 00036870004 as event file already exists in directory.
#
# 	Index 320
# Glitch 277
# Processing ObsID: 03112530139
# Skipping ObsID 03112530139 as event file already exists in directory.
#
# 	Index 321
# Glitch 277
# Processing ObsID: 03112532246
# Skipping ObsID 03112532246 as event file already exists in directory.
#
# 	Index 322
# Glitch 277
# Processing ObsID: 00016629003
# Skipping ObsID 00016629003 as event file already exists in directory.
#
# 	Index 323
# Glitch 277
# Processing ObsID: 00097371004
# Skipping ObsID 00097371004 as event file already exists in directory.
#
# 	Index 324
# Glitch 277
# Processing ObsID: 00031844016
# Skipping ObsID 00031844016 as event file already exists in directory.
#
# 	Index 325
# Glitch 277
# Processing ObsID: 00097410002
# Skipping ObsID 00097410002 as event file already exists in directory.
#
# 	Index 326
# Glitch 277
# Processing ObsID: 00097486002
# Skipping ObsID 00097486002 as event file already exists in directory.
#
# 	Index 327
# Glitch 277
# Processing ObsID: 00097379003
# Skipping ObsID 00097379003 as event file already exists in directory.
#
# 	Index 328
# Glitch 277
# Processing ObsID: 00032671095
# Skipping ObsID 00032671095 as event file already exists in directory.
#
# 	Index 329
# Glitch 277
# Processing ObsID: 03111188072
# Skipping ObsID 03111188072 as event file already exists in directory.
#
# 	Index 330
# Glitch 277
# Processing ObsID: 03111108074
# Skipping ObsID 03111108074 as event file already exists in directory.
#
# 	Index 331
# Glitch 277
# Processing ObsID: 03111155072
# Skipping ObsID 03111155072 as event file already exists in directory.
#
# 	Index 332
# Glitch 277
# Processing ObsID: 03112105055
# Skipping ObsID 03112105055 as event file already exists in directory.
#
# 	Index 333
# Glitch 277
# Processing ObsID: 00010375120
# Skipping ObsID 00010375120 as event file already exists in directory.
#
# 	Index 334
# Glitch 277
# Processing ObsID: 00010375120
# Skipping ObsID 00010375120 as event file already exists in directory.
#
# 	Index 335
# Glitch 277
# Processing ObsID: 00074169039
# Skipping ObsID 00074169039 as event file already exists in directory.
#
# 	Index 336
# Glitch 277
# Processing ObsID: 00097441001
# Skipping ObsID 00097441001 as event file already exists in directory.
#
# 	Index 337
# Glitch 277
# Processing ObsID: 03112530137
# Skipping ObsID 03112530137 as event file already exists in directory.
#
# 	Index 338
# Glitch 277
# Processing ObsID: 03111092072
# Skipping ObsID 03111092072 as event file already exists in directory.
#
# 	Index 339
# Glitch 277
# Processing ObsID: 00016624003
# Skipping ObsID 00016624003 as event file already exists in directory.
#
# 	Index 340
# Glitch 277
# Processing ObsID: 00016624003
# Skipping ObsID 00016624003 as event file already exists in directory.
#
# 	Index 341
# Glitch 277
# Processing ObsID: 00040822008
# Skipping ObsID 00040822008 as event file already exists in directory.
#
# 	Index 342
# Glitch 277
# Processing ObsID: 00016500018
# Skipping ObsID 00016500018 as event file already exists in directory.
#
# 	Index 343
# Glitch 277
# Processing ObsID: 03112543013
# Skipping ObsID 03112543013 as event file already exists in directory.
#
# 	Index 344
# Glitch 277
# Processing ObsID: 00014978054
# Skipping ObsID 00014978054 as event file already exists in directory.
#
# 	Index 345
# Glitch 277
# Processing ObsID: 00097753003
# Skipping ObsID 00097753003 as event file already exists in directory.
#
# 	Index 346
# Glitch 277
# Processing ObsID: 00035344143
# Skipping ObsID 00035344143 as event file already exists in directory.
#
# 	Index 347
# Glitch 277
# Processing ObsID: 00015007034
# Skipping ObsID 00015007034 as event file already exists in directory.
#
# 	Index 348
# Glitch 277
# Processing ObsID: 00035461140
# Skipping ObsID 00035461140 as event file already exists in directory.
#
# 	Index 349
# Glitch 277
# Processing ObsID: 00010717003
# Skipping ObsID 00010717003 as event file already exists in directory.
#
# 	Index 350
# Glitch 277
# Processing ObsID: 03112576003
# Skipping ObsID 03112576003 as event file already exists in directory.
#
# 	Index 351
# Glitch 277
# Processing ObsID: 00031540215
# Skipping ObsID 00031540215 as event file already exists in directory.
#
# 	Index 352
# Glitch 277
# Processing ObsID: 03112532244
# Skipping ObsID 03112532244 as event file already exists in directory.
#
# 	Index 353
# Glitch 277
# Processing ObsID: 00097731004
# Skipping ObsID 00097731004 as event file already exists in directory.
#
# 	Index 354
# Glitch 277
# Processing ObsID: 00015026076
# Skipping ObsID 00015026076 as event file already exists in directory.
#
# 	Index 355
# Glitch 277
# Processing ObsID: 00015026076
# Skipping ObsID 00015026076 as event file already exists in directory.
#
# 	Index 356
# Glitch 277
# Processing ObsID: 00016609004
# Skipping ObsID 00016609004 as event file already exists in directory.
#
# 	Index 357
# Glitch 277
# Processing ObsID: 00097753003
# Skipping ObsID 00097753003 as event file already exists in directory.
#
# 	Index 358
# Glitch 277
# Processing ObsID: 00038932003
# Skipping ObsID 00038932003 as event file already exists in directory.
#
# 	Index 359
# Glitch 277
# Processing ObsID: 00038932003
# Skipping ObsID 00038932003 as event file already exists in directory.
#
# 	Index 360
# Glitch 277
# Processing ObsID: 00030835212
# Skipping ObsID 00030835212 as event file already exists in directory.
#
# 	Index 361
# Glitch 277
# Processing ObsID: 00037354074
# Skipping ObsID 00037354074 as event file already exists in directory.
#
# 	Index 362
# Glitch 277
# Processing ObsID: 00089883002
# Skipping ObsID 00089883002 as event file already exists in directory.
#
# 	Index 363
# Glitch 277
# Processing ObsID: 00097401005
# Skipping ObsID 00097401005 as event file already exists in directory.
#
# 	Index 364
# Glitch 277
# Processing ObsID: 03112526081
# Skipping ObsID 03112526081 as event file already exists in directory.
#
# 	Index 365
# Glitch 277
# Processing ObsID: 00016582003
# Skipping ObsID 00016582003 as event file already exists in directory.
#
# 	Index 366
# Glitch 277
# Processing ObsID: 00016624002
# Skipping ObsID 00016624002 as event file already exists in directory.
#
# 	Index 367
# Glitch 277
# Processing ObsID: 00097644005
# Skipping ObsID 00097644005 as event file already exists in directory.
#
# 	Index 368
# Glitch 277
# Processing ObsID: 00016624002
# Skipping ObsID 00016624002 as event file already exists in directory.
#
# 	Index 369
# Glitch 277
# Processing ObsID: 03112556008
# Skipping ObsID 03112556008 as event file already exists in directory.
#
# 	Index 370
# Glitch 277
# Processing ObsID: 03112558021
# Skipping ObsID 03112558021 as event file already exists in directory.
#
# 	Index 371
# Glitch 277
# Processing ObsID: 00097500002
# Skipping ObsID 00097500002 as event file already exists in directory.
#
# 	Index 372
# Glitch 277
# Processing ObsID: 00081161001
# Skipping ObsID 00081161001 as event file already exists in directory.
#
# 	Index 373
# Glitch 277
# Processing ObsID: 00081161001
# Skipping ObsID 00081161001 as event file already exists in directory.
#
# 	Index 374
# Glitch 277
# Processing ObsID: 00097455004
# Skipping ObsID 00097455004 as event file already exists in directory.
#
# 	Index 375
# Glitch 277
# Processing ObsID: 00097472001
# Skipping ObsID 00097472001 as event file already exists in directory.
#
# 	Index 376
# Glitch 277
# Processing ObsID: 00097330009
# Skipping ObsID 00097330009 as event file already exists in directory.
#
# 	Index 377
# Glitch 277
# Processing ObsID: 00097330009
# Skipping ObsID 00097330009 as event file already exists in directory.
#
# 	Index 378
# Glitch 277
# Processing ObsID: 00016433002
# Skipping ObsID 00016433002 as event file already exists in directory.
#
# 	Index 379
# Glitch 277
# Processing ObsID: 00049689010
# Skipping ObsID 00049689010 as event file already exists in directory.
#
# 	Index 380
# Glitch 277
# Processing ObsID: 00016585009
# Skipping ObsID 00016585009 as event file already exists in directory.
#
# 	Index 381
# Glitch 277
# Processing ObsID: 00016585009
# Skipping ObsID 00016585009 as event file already exists in directory.
#
# 	Index 382
# Glitch 277
# Processing ObsID: 00074054139
# Skipping ObsID 00074054139 as event file already exists in directory.
#
# 	Index 383
# Glitch 277
# Processing ObsID: 00097377005
# Skipping ObsID 00097377005 as event file already exists in directory.
#
# 	Index 384
# Glitch 277
# Processing ObsID: 00037570089
# Skipping ObsID 00037570089 as event file already exists in directory.
#
# 	Index 385
# Glitch 277
# Processing ObsID: 05000464004
# Skipping ObsID 05000464004 as event file already exists in directory.
#
# 	Index 386
# Glitch 277
# Processing ObsID: 03112526075
# Skipping ObsID 03112526075 as event file already exists in directory.
#
# 	Index 387
# Glitch 277
# Processing ObsID: 00016601037
# Skipping ObsID 00016601037 as event file already exists in directory.
#
# 	Index 388
# Glitch 277
# Processing ObsID: 00097137188
# Skipping ObsID 00097137188 as event file already exists in directory.
#
# 	Index 389
# Glitch 277
# Processing ObsID: 00076494021
# Skipping ObsID 00076494021 as event file already exists in directory.
#
# 	Index 390
# Glitch 277
# Processing ObsID: 03112526075
# Skipping ObsID 03112526075 as event file already exists in directory.
#
# 	Index 391
# ...
# Processing ObsID: 00049547004
# Skipping ObsID 00049547004 as event file already exists in directory.
#
# 	Index 903
# Glitch 277
# Processing ObsID: 00014440017
# Skipping ObsID 00014440017 as event file already exists in directory.
#
# 	Index 904
# Glitch 277
# Processing ObsID: 00013898002
# Skipping ObsID 00013898002 as event file already exists in directory.
#
# 	Index 905
# Glitch 277
# Processing ObsID: 00016502001
# Skipping ObsID 00016502001 as event file already exists in directory.
#
# 	Index 906
# Glitch 277
# Processing ObsID: 00084036004
# Skipping ObsID 00084036004 as event file already exists in directory.
#
# 	Index 907
# Glitch 277
# Processing ObsID: 00015260063
# Skipping ObsID 00015260063 as event file already exists in directory.
#
# 	Index 908
# Glitch 277
# Processing ObsID: 00049680006
# Skipping ObsID 00049680006 as event file already exists in directory.
#
# 	Index 909
# Glitch 277
# Processing ObsID: 00015378049
# Skipping ObsID 00015378049 as event file already exists in directory.
#
# 	Index 910
# Glitch 277
# Processing ObsID: 03111888025
# Skipping ObsID 03111888025 as event file already exists in directory.
#
# 	Index 911
# Glitch 277
# Processing ObsID: 03111888025
# Skipping ObsID 03111888025 as event file already exists in directory.
#
# 	Index 912
# Glitch 277
# Processing ObsID: 01212898001
# Skipping ObsID 01212898001 as event file already exists in directory.
#
# 	Index 913
# Glitch 277
# Processing ObsID: 01212898000
# Skipping ObsID 01212898000 as event file already exists in directory.
#
# 	Index 914
# Glitch 277
# Processing ObsID: 03112532173
# Skipping ObsID 03112532173 as event file already exists in directory.
#
# 	Index 915
# Glitch 277
# Processing ObsID: 00097191051
# Skipping ObsID 00097191051 as event file already exists in directory.
#
# 	Index 916
# Glitch 277
# Processing ObsID: 00097191051
# Skipping ObsID 00097191051 as event file already exists in directory.
#
# 	Index 917
# Glitch 277
# Processing ObsID: 00049737001
# Skipping ObsID 00049737001 as event file already exists in directory.
#
# 	Index 918
# Glitch 277
# Processing ObsID: 03112532173
# Skipping ObsID 03112532173 as event file already exists in directory.
#
# 	Index 919
# Glitch 277
# Processing ObsID: 03112532173
# Skipping ObsID 03112532173 as event file already exists in directory.
#
# 	Index 920
# Glitch 277
# Processing ObsID: 00037570029
# Skipping ObsID 00037570029 as event file already exists in directory.
#
# 	Index 921
# Glitch 277
# Processing ObsID: 03112499011
# Skipping ObsID 03112499011 as event file already exists in directory.
#
# 	Index 922
# Glitch 277
# Processing ObsID: 00016496005
# Skipping ObsID 00016496005 as event file already exists in directory.
#
# 	Index 923
# Glitch 277
# Processing ObsID: 00034134074
# Skipping ObsID 00034134074 as event file already exists in directory.
#
# 	Index 924
# Glitch 277
# Processing ObsID: 00034134074
# Skipping ObsID 00034134074 as event file already exists in directory.
#
# 	Index 925
# Glitch 277
# Processing ObsID: 00016444006
# Skipping ObsID 00016444006 as event file already exists in directory.
#
# 	Index 926
# Glitch 277
# Processing ObsID: 01212488000
# Skipping ObsID 01212488000 as event file already exists in directory.
#
# 	Index 927
# Glitch 277
# Processing ObsID: 00016489001
# Skipping ObsID 00016489001 as event file already exists in directory.
#
# 	Index 928
# Glitch 277
# Processing ObsID: 00016473011
# Skipping ObsID 00016473011 as event file already exists in directory.
#
# 	Index 929
# Glitch 277
# Processing ObsID: 00095662086
# Skipping ObsID 00095662086 as event file already exists in directory.
#
# 	Index 930
# Glitch 277
# Processing ObsID: 00082667007
# Skipping ObsID 00082667007 as event file already exists in directory.
#
# 	Index 931
# Glitch 277
# Processing ObsID: 03103185001
# Skipping ObsID 03103185001 as event file already exists in directory.
#
# 	Index 932
# Glitch 277
# Processing ObsID: 00097137101
# Skipping ObsID 00097137101 as event file already exists in directory.
#
# 	Index 933
# Glitch 277
# Processing ObsID: 00016488003
# Skipping ObsID 00016488003 as event file already exists in directory.
#
# 	Index 934
# Glitch 277
# Processing ObsID: 03111084064
# Skipping ObsID 03111084064 as event file already exists in directory.
#
# 	Index 935
# Glitch 277
# Processing ObsID: 03111198064
# Skipping ObsID 03111198064 as event file already exists in directory.
#
# 	Index 936
# Glitch 277
# Processing ObsID: 00082531005
# Skipping ObsID 00082531005 as event file already exists in directory.
#
# 	Index 937
# Glitch 277
# Processing ObsID: 00014217073
# Skipping ObsID 00014217073 as event file already exists in directory.
#
# 	Index 938
# Glitch 277
# Processing ObsID: 00016447014
# Skipping ObsID 00016447014 as event file already exists in directory.
#
# 	Index 939
# Glitch 277
# Processing ObsID: 00016447014
# Skipping ObsID 00016447014 as event file already exists in directory.
#
# 	Index 940
# Glitch 277
# Processing ObsID: 00015411136
# Skipping ObsID 00015411136 as event file already exists in directory.
#
# 	Index 941
# Glitch 277
# Processing ObsID: 00016472005
# Skipping ObsID 00016472005 as event file already exists in directory.
#
# 	Index 942
# Glitch 277
# Processing ObsID: 00021659001
# Skipping ObsID 00021659001 as event file already exists in directory.
#
# 	Index 943
# Glitch 277
# Processing ObsID: 03112523099
# Skipping ObsID 03112523099 as event file already exists in directory.
#
# 	Index 944
# Glitch 277
# Processing ObsID: 03110085005
# Skipping ObsID 03110085005 as event file already exists in directory.
#
# 	Index 945
# Glitch 277
# Processing ObsID: 03110085005
# Skipping ObsID 03110085005 as event file already exists in directory.
#
# 	Index 946
# Glitch 277
# Processing ObsID: 03110085005
# Skipping ObsID 03110085005 as event file already exists in directory.
#
# 	Index 947
# Glitch 277
# Processing ObsID: 00097190029
# Skipping ObsID 00097190029 as event file already exists in directory.
#
# 	Index 948
# Glitch 277
# Processing ObsID: 00097190029
# Skipping ObsID 00097190029 as event file already exists in directory.
#
# 	Index 949
# Glitch 277
# Processing ObsID: 00021656001
# Skipping ObsID 00021656001 as event file already exists in directory.
#
# 	Index 950
# Glitch 277
# Processing ObsID: 00021654001
# Skipping ObsID 00021654001 as event file already exists in directory.
#
# 	Index 951
# Glitch 277
# Processing ObsID: 00021653001
# Skipping ObsID 00021653001 as event file already exists in directory.
#
# 	Index 952
# Glitch 277
# Processing ObsID: 00037570027
# Skipping ObsID 00037570027 as event file already exists in directory.
#
# 	Index 953
# Glitch 277
# Processing ObsID: 03106595002
# Skipping ObsID 03106595002 as event file already exists in directory.
#
# 	Index 954
# Glitch 277
# Processing ObsID: 03106595002
# Skipping ObsID 03106595002 as event file already exists in directory.
#
# 	Index 955
# Glitch 277
# Processing ObsID: 00031690027
# Skipping ObsID 00031690027 as event file already exists in directory.
#
# 	Index 956
# Glitch 277
# Processing ObsID: 00016447010
# Skipping ObsID 00016447010 as event file already exists in directory.
#
# 	Index 957
# Glitch 277
# Processing ObsID: 00016447008
# Skipping ObsID 00016447008 as event file already exists in directory.
#
# 	Index 958
# Glitch 277
# Processing ObsID: 00016459003
# Skipping ObsID 00016459003 as event file already exists in directory.
#
# 	Index 959
# Glitch 277
# Processing ObsID: 00015926003
# Skipping ObsID 00015926003 as event file already exists in directory.
#
# 	Index 960
# Glitch 277
# Processing ObsID: 00035013044
# Skipping ObsID 00035013044 as event file already exists in directory.
#
# 	Index 961
# Glitch 277
# Processing ObsID: 03112335007
# Skipping ObsID 03112335007 as event file already exists in directory.
#
# 	Index 962
# Glitch 277
# Processing ObsID: 00097080001
# Skipping ObsID 00097080001 as event file already exists in directory.
#
# 	Index 963
# Glitch 277
# Processing ObsID: 00037570024
# Skipping ObsID 00037570024 as event file already exists in directory.
#
# 	Index 964
# Glitch 277
# Processing ObsID: 00048056014
# Skipping ObsID 00048056014 as event file already exists in directory.
#
# 	Index 965
# Glitch 277
# Processing ObsID: 00084151003
# Skipping ObsID 00084151003 as event file already exists in directory.
#
# 	Index 966
# Glitch 277
# Processing ObsID: 00076960001
# Skipping ObsID 00076960001 as event file already exists in directory.
#
# 	Index 967
# Glitch 277
# Processing ObsID: 00047175005
# Skipping ObsID 00047175005 as event file already exists in directory.
#
# 	Index 968
# Glitch 277
# Processing ObsID: 03109833012
# Skipping ObsID 03109833012 as event file already exists in directory.
#
# 	Index 969
# Glitch 277
# Processing ObsID: 00041571012
# Skipping ObsID 00041571012 as event file already exists in directory.
#
# 	Index 970
# Glitch 277
# Processing ObsID: 01210276001
# Skipping ObsID 01210276001 as event file already exists in directory.
#
# 	Index 971
# Glitch 277
# Processing ObsID: 03111158061
# Skipping ObsID 03111158061 as event file already exists in directory.
#
# 	Index 972
# Glitch 277
# Processing ObsID: 01210276000
# Skipping ObsID 01210276000 as event file already exists in directory.
#
# 	Index 973
# Glitch 277
# Processing ObsID: 00016100061
# Skipping ObsID 00016100061 as event file already exists in directory.
#
# 	Index 974
# Glitch 277
# Processing ObsID: 00013558189
# Skipping ObsID 00013558189 as event file already exists in directory.
#
# 	Index 975
# Glitch 277
# Processing ObsID: 00016095032
# Skipping ObsID 00016095032 as event file already exists in directory.
#
# 	Index 976
# Glitch 277
# Processing ObsID: 00013558185
# Skipping ObsID 00013558185 as event file already exists in directory.
#
# 	Index 977
# Glitch 277
# Processing ObsID: 00015260062
# Skipping ObsID 00015260062 as event file already exists in directory.
#
# 	Index 978
# Glitch 277
# Processing ObsID: 03112355011
# Skipping ObsID 03112355011 as event file already exists in directory.
#
# 	Index 979
# Glitch 277
# Processing ObsID: 00015260062
# Skipping ObsID 00015260062 as event file already exists in directory.
#
# 	Index 980
# Glitch 277
# Processing ObsID: 00041692004
# Skipping ObsID 00041692004 as event file already exists in directory.
#
# 	Index 981
# Glitch 277
# Processing ObsID: 00035461133
# Skipping ObsID 00035461133 as event file already exists in directory.
#
# 	Index 982
# Glitch 277
# Processing ObsID: 00016326013
# Skipping ObsID 00016326013 as event file already exists in directory.
#
# 	Index 983
# Glitch 277
# Processing ObsID: 03112355011
# Skipping ObsID 03112355011 as event file already exists in directory.
#
# 	Index 984
# Glitch 277
# Processing ObsID: 01209900000
# Skipping ObsID 01209900000 as event file already exists in directory.
#
# 	Index 985
# Glitch 277
# Processing ObsID: 03112355009
# Skipping ObsID 03112355009 as event file already exists in directory.
#
# 	Index 986
# Glitch 277
# Processing ObsID: 00016423008
# Skipping ObsID 00016423008 as event file already exists in directory.
#
# 	Index 987
# Glitch 277
# Processing ObsID: 00036557017
# Skipping ObsID 00036557017 as event file already exists in directory.
#
# 	Index 988
# Glitch 277
# Processing ObsID: 00016464006
# Skipping ObsID 00016464006 as event file already exists in directory.
#
# 	Index 989
# Glitch 277
# Processing ObsID: 00016477006
# Skipping ObsID 00016477006 as event file already exists in directory.
#
# 	Index 990
# Glitch 277
# Processing ObsID: 00016022057
# Skipping ObsID 00016022057 as event file already exists in directory.
#
# 	Index 991
# Glitch 277
# Processing ObsID: 00080913001
# Skipping ObsID 00080913001 as event file already exists in directory.
#
# 	Index 992
# Glitch 277
# Processing ObsID: 00016421004
# Skipping ObsID 00016421004 as event file already exists in directory.
#
# 	Index 993
# Glitch 277
# Processing ObsID: 00031540177
# Skipping ObsID 00031540177 as event file already exists in directory.
#
# 	Index 994
# Glitch 277
# Processing ObsID: 00010905247
# Skipping ObsID 00010905247 as event file already exists in directory.
#
# 	Index 995
# Glitch 277
# Processing ObsID: 00096992059
# Skipping ObsID 00096992059 as event file already exists in directory.
#
# 	Index 996
# Glitch 277
# Processing ObsID: 00096992059
# Skipping ObsID 00096992059 as event file already exists in directory.
#
# 	Index 997
# Glitch 277
# Processing ObsID: 03111973023
# Skipping ObsID 03111973023 as event file already exists in directory.
#
# 	Index 998
# Glitch 277
# Processing ObsID: 03112523089
# Skipping ObsID 03112523089 as event file already exists in directory.
#
# 	Index 999
# Glitch 277
# Processing ObsID: 03112262003
# Skipping ObsID 03112262003 as event file already exists in directory.
#
# 	Index 1000
# Glitch 277
# Processing ObsID: 00035011088
# Skipping ObsID 00035011088 as event file already exists in directory.
#
# 	Index 1001
# Glitch 277
# Processing ObsID: 00010439023
# Skipping ObsID 00010439023 as event file already exists in directory.
#
# 	Index 1002
# Glitch 277
# Processing ObsID: 01208389007
# Skipping ObsID 01208389007 as event file already exists in directory.
#
# 	Index 1003
# Glitch 277
# Processing ObsID: 01208389007
# Skipping ObsID 01208389007 as event file already exists in directory.
#
# 	Index 1004
# Glitch 277
# Processing ObsID: 00075518008
# Skipping ObsID 00075518008 as event file already exists in directory.
#
# 	Index 1005
# Glitch 277
# Processing ObsID: 00075518008
# Skipping ObsID 00075518008 as event file already exists in directory.
#
# 	Index 1006
# Glitch 277
# Processing ObsID: 01209406000
# Skipping ObsID 01209406000 as event file already exists in directory.
#
# 	Index 1007
# Glitch 277
# Processing ObsID: 00097137087
# Skipping ObsID 00097137087 as event file already exists in directory.
#
# 	Index 1008
# Glitch 277
# Processing ObsID: 01208389005
# Skipping ObsID 01208389005 as event file already exists in directory.
#
# 	Index 1009
# Glitch 277
# Processing ObsID: 00088915065
# Skipping ObsID 00088915065 as event file already exists in directory.
#
# 	Index 1010
# Glitch 277
# Processing ObsID: 03112265007
# Skipping ObsID 03112265007 as event file already exists in directory.
#
# 	Index 1011
# Glitch 277
# Processing ObsID: 03112265007
# Skipping ObsID 03112265007 as event file already exists in directory.
#
# 	Index 1012
# Glitch 277
# Processing ObsID: 03111157060
# Skipping ObsID 03111157060 as event file already exists in directory.
#
# 	Index 1013
# Glitch 277
# Processing ObsID: 00089708001
# Skipping ObsID 00089708001 as event file already exists in directory.
#
# 	Index 1014
# Glitch 277
# Processing ObsID: 00032249155
# Skipping ObsID 00032249155 as event file already exists in directory.
#
# 	Index 1015
# Glitch 277
# Processing ObsID: 00032249155
# Skipping ObsID 00032249155 as event file already exists in directory.
#
# 	Index 1016
# Glitch 277
# Processing ObsID: 03112198019
# Skipping ObsID 03112198019 as event file already exists in directory.
#
# 	Index 1017
# Glitch 277
# Processing ObsID: 00016426005
# Skipping ObsID 00016426005 as event file already exists in directory.
#
# 	Index 1018
# Glitch 277
# Processing ObsID: 05000436003
# Skipping ObsID 05000436003 as event file already exists in directory.
#
# 	Index 1019
# Glitch 277
# Processing ObsID: 01209045000
# Downloading 01209045000 from GUANO.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 NEWmain(resolution=resolution, total=total, begin=begin, end=end)
#
# Cell In[25], line 47, in NEWmain(resolution, total, begin, end)
#      45     print(f"Downloading {obsid} from GUANO.")
#      46     # Download event file from GUANO
# ---> 47     data = Data(obsid=obsid, bat=True, outdir=scratchbase, clobber=True)
#      48     print(f"Downloaded event file to: {event_url}")
#      49 except Exception as e:
#
# File /storage/work/kbf5380/.conda/envs/STARproj/lib/python3.10/site-packages/swifttools/swift_too/swift_data.py:271, in Swift_Data.__init__(self, *args, **kwargs)
#     268 # See if we pass validation from the constructor, but don't record
#     269 # errors if we don't
#     270 if self.validate():
# --> 271     self.submit()
#     272     # ...and if requested, download the data
#     273     if self.fetch:
#
# File /storage/work/kbf5380/.conda/envs/STARproj/lib/python3.10/site-packages/swifttools/swift_too/api_common.py:519, in TOOAPI_Baseclass.submit(self, timeout, post)
#     517 # Check if the Queued job is complete for up to *timeout* seconds (120s default)
#     518 while datetime.now().timestamp() - ustart < self.timeout and not self.complete:
# --> 519     sleep(1)
#     521 # If the job is still Queued, report that it has timed out as an error
#     522 if self.status == "Queued" or self.status == "Processing":
#
# KeyboardInterrupt:
