# %% [markdown]
# This notebook generates detector plane images (dpis) of confirmed SWIFT Burst Alert Telescope (BAT) gamma ray bursts (GRBs) as posted by swift.gsfc.nasa.gov.
#
# The GRB time intervals are extracted using their event data provided by the website and are centered using a 64ms time window. The DPI is constructed from the DETX and DETY coordinates of each detected event.
#
# Two resolutions are available, corresponding to two support vector machine models:
#
# "original" : full detector plane resolution (286 x 173)
#
# "lowRES" : binned resolution (~ 16 x 16)

# %%
resolution = "lowRES"  # Choose between "original" or "lowRES"
total = 250  # Number of dpi files to save

# %%
import os, io, requests
import numpy as np
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup
from astropy.table import Table
from astropy.io import fits

# %% [markdown]
# ### helper functions

# %%
base_url = "https://swift.gsfc.nasa.gov/results/batgrbcat/"

grbdpi_folder = "GRBdpi" if resolution == "original" else "GRBdpi_lowRES"
os.makedirs(grbdpi_folder, exist_ok=True)

def get_grb_list():
    response = requests.get(base_url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        table = soup.find('table')
        if not table:
            print("No GRB table found.")
            return []
    
    grbs = []
    for row in table.find_all('tr'):
        cols = row.find_all('td')
        if len(cols) > 2:
            name = cols[0].text.strip()
            trigid = cols[1].text.strip()
            if name and trigid.isdigit():
                grbs.append((name, trigid))
    
    return grbs
    
    
def det2dpi_sands_ebins(tab, ebins, weights=None):

    detxs_by_sand0 = np.arange(0, 286 - 15, 18)
    detxs_by_sand1 = detxs_by_sand0 + 15
    xbins = np.append(detxs_by_sand0, [detxs_by_sand1[-1]])

    detys_by_sand0 = np.arange(0, 173 - 7, 11)
    detys_by_sand1 = detys_by_sand0 + 7
    ybins = np.append(detys_by_sand0, [detys_by_sand1[-1]])
    
    sand_dpis = np.swapaxes(
        np.histogramdd([tab["DETX"], tab["DETY"], tab['ENERGY']], bins=[xbins, ybins, ebins], weights=weights)[
            0
        ],
        0,
        1,
    )

    return sand_dpis


def gettrig(trigger_id):      # the path to an event file from the base url includes
    tid_str = str(trigger_id) # three zeros after the tigger ID, and as many preceding
    padded = tid_str + '000'  # the ID to total 11 digits in the event file name
    trigstring = padded.zfill(11)  # *excludes those with differing trigger IDs*
    return trigstring


def process_dpis(event_table, index, resolution, dpi_path):
    global saved_dpis
    
    if saved_dpis >= total:
        print(f"Reached {total} GRB DPIs.")
        return
    
    if 'DETX' in event_table.columns and 'DETY' in event_table.columns:
        if event_table['DETX'].size == 0 or event_table['DETY'].size == 0:
            print(f"Warning: Empty DETX/DETY for GRB {index}")
            return

        if resolution == "original":
            xbins = np.arange(286 + 1) - 0.5
            ybins = np.arange(173 + 1) - 0.5
            dpi = plt.hist2d(event_table['DETX'], event_table['DETY'], bins=[xbins, ybins], vmin=0, vmax=2)[0]
            plt.close()
        else:
            ebins = [15, 50, 350]
            dpi = det2dpi_sands_ebins(event_table, ebins)

        np.save(dpi_path, dpi)
        print(f"Saved {dpi_path}")
        saved_dpis += 1
    else:
        print(f"Missing DETX/DETY columns for GRB {index}")

        
def process_grb(grb_name, trigger_id, index, resolution, total, grbdpi_folder):
    global saved_dpis
    
    dpi_filename = f"GRBdpi{'_lowRES' if resolution == 'lowRES' else ''}_{saved_dpis + 1}.npy"
    dpi_path = os.path.join(grbdpi_folder, dpi_filename)
    
    if os.path.exists(dpi_path):
        print(f"Skipping GRB {grb_name} (dpi {index}) because the DPI file already exists.")
        saved_dpis += 1
        return
    
    try: 
        trigstring = gettrig(trigger_id)
        event_url = f"{base_url}{grb_name}/data_product/{trigstring}/bat/event/sw{trigstring}bevshsp_uf.evt"

        response = requests.get(event_url)
        response.raise_for_status()
    
        with fits.open(io.BytesIO(response.content)) as hdul:
            trig_time = hdul[1].header['TRIGTIME']
            event_table = Table(hdul[1].data)
            
            event_table = event_table[(event_table['TIME'] >= trig_time) & 
                                      (event_table['TIME'] <= trig_time + 0.064)]  # 64 ms dpi
            
            print(f"Number of events in 64ms window: {len(event_table)}")
            process_dpis(event_table, index, resolution, dpi_path)
            
    except Exception as e:
        print(f"Skipping {grb_name}: {e}")

# %%
def MyMain(resolution="original", total=300):   # default values
    global saved_dpis
    saved_dpis = 0
    assert resolution in ["original", "lowRES"], "Resolution must be 'original' or 'lowRES'"
     
    grbdpi_folder = "GRBdpi" if resolution == "original" else "GRBdpi_lowRES"
    os.makedirs(grbdpi_folder, exist_ok=True)
        
    if saved_dpis >= total:
        print(f"{saved_dpis} GRB DPI files already exist in '{grbdpi_folder}'. Done.")
        return
    
    grbs = get_grb_list()
    
    for i, (name, trigid) in enumerate(grbs, start=1):
        if saved_dpis >= total:
            break

        print(f"\tProcessing GRB {name} (index {i})...")  
        process_grb(name, trigid, i, resolution, total, grbdpi_folder)
    
    print(f"Processing complete. {saved_dpis} GRB dpi files saved.")

# %%
MyMain(resolution=resolution, total=total)
# Out:
# 	Processing GRB GRB241006A (index 1)...
# Skipping GRB GRB241006A (dpi 1) because the DPI file already exists.
# 	Processing GRB GRB241002A (index 2)...
# Skipping GRB GRB241002A (dpi 2) because the DPI file already exists.
# 	Processing GRB GRB240912A (index 3)...
# Skipping GRB GRB240912A (dpi 3) because the DPI file already exists.
# 	Processing GRB GRB240905E (index 4)...
# Skipping GRB GRB240905E (dpi 4) because the DPI file already exists.
# 	Processing GRB GRB240904A (index 5)...
# Skipping GRB GRB240904A (dpi 5) because the DPI file already exists.
# 	Processing GRB GRB240829A (index 6)...
# Skipping GRB GRB240829A (dpi 6) because the DPI file already exists.
# 	Processing GRB GRB240825A (index 7)...
# Skipping GRB GRB240825A (dpi 7) because the DPI file already exists.
# 	Processing GRB GRB240824A (index 8)...
# Skipping GRB GRB240824A (dpi 8) because the DPI file already exists.
# 	Processing GRB GRB240811A (index 9)...
# Skipping GRB GRB240811A (dpi 9) because the DPI file already exists.
# 	Processing GRB GRB240809A (index 10)...
# Skipping GRB GRB240809A (dpi 10) because the DPI file already exists.
# 	Processing GRB GRB240805B (index 11)...
# Skipping GRB GRB240805B (dpi 11) because the DPI file already exists.
# 	Processing GRB GRB240805A (index 12)...
# Skipping GRB GRB240805A (dpi 12) because the DPI file already exists.
# 	Processing GRB GRB240730A (index 13)...
# Skipping GRB GRB240730A (dpi 13) because the DPI file already exists.
# 	Processing GRB GRB240727A (index 14)...
# Skipping GRB GRB240727A (dpi 14) because the DPI file already exists.
# 	Processing GRB GRB240720A (index 15)...
# Skipping GRB GRB240720A (dpi 15) because the DPI file already exists.
# 	Processing GRB GRB240712A (index 16)...
# Skipping GRB GRB240712A (dpi 16) because the DPI file already exists.
# 	Processing GRB GRB240624A (index 17)...
# Skipping GRB GRB240624A (dpi 17) because the DPI file already exists.
# 	Processing GRB GRB240529A (index 18)...
# Skipping GRB GRB240529A (dpi 18) because the DPI file already exists.
# 	Processing GRB GRB240523A (index 19)...
# Skipping GRB GRB240523A (dpi 19) because the DPI file already exists.
# 	Processing GRB GRB240516A (index 20)...
# Skipping GRB GRB240516A (dpi 20) because the DPI file already exists.
# 	Processing GRB GRB240511A (index 21)...
# Skipping GRB GRB240511A (dpi 21) because the DPI file already exists.
# 	Processing GRB GRB240421B (index 22)...
# Skipping GRB GRB240421B (dpi 22) because the DPI file already exists.
# 	Processing GRB GRB240419B (index 23)...
# Skipping GRB GRB240419B (dpi 23) because the DPI file already exists.
# 	Processing GRB GRB240419A (index 24)...
# Skipping GRB GRB240419A (dpi 24) because the DPI file already exists.
# 	Processing GRB GRB240418A (index 25)...
# Skipping GRB GRB240418A (dpi 25) because the DPI file already exists.
# 	Processing GRB GRB240415A (index 26)...
# Skipping GRB GRB240415A (dpi 26) because the DPI file already exists.
# 	Processing GRB GRB240414A (index 27)...
# Skipping GRB GRB240414A (dpi 27) because the DPI file already exists.
# 	Processing GRB GRB240411B (index 28)...
# Skipping GRB GRB240411B (dpi 28) because the DPI file already exists.
# 	Processing GRB GRB240222A (index 29)...
# Skipping GRB GRB240222A (dpi 29) because the DPI file already exists.
# 	Processing GRB GRB240218A (index 30)...
# Skipping GRB GRB240218A (dpi 30) because the DPI file already exists.
# 	Processing GRB GRB240205B (index 31)...
# Skipping GRB GRB240205B (dpi 31) because the DPI file already exists.
# 	Processing GRB GRB240204A (index 32)...
# Skipping GRB GRB240204A (dpi 32) because the DPI file already exists.
# 	Processing GRB GRB240123A (index 33)...
# Skipping GRB GRB240123A (dpi 33) because the DPI file already exists.
# 	Processing GRB GRB240112C (index 34)...
# Skipping GRB GRB240112C (dpi 34) because the DPI file already exists.
# 	Processing GRB GRB240109A (index 35)...
# Skipping GRB GRB240109A (dpi 35) because the DPI file already exists.
# 	Processing GRB GRB240102A (index 36)...
# Skipping GRB GRB240102A (dpi 36) because the DPI file already exists.
# 	Processing GRB GRB240101B (index 37)...
# Skipping GRB GRB240101B (dpi 37) because the DPI file already exists.
# 	Processing GRB GRB240101A (index 38)...
# Skipping GRB GRB240101A (dpi 38) because the DPI file already exists.
# 	Processing GRB GRB231230A (index 39)...
# Skipping GRB GRB231230A (dpi 39) because the DPI file already exists.
# 	Processing GRB GRB231216A (index 40)...
# Skipping GRB GRB231216A (dpi 40) because the DPI file already exists.
# 	Processing GRB GRB231215A (index 41)...
# Skipping GRB GRB231215A (dpi 41) because the DPI file already exists.
# 	Processing GRB GRB231214A (index 42)...
# Skipping GRB GRB231214A (dpi 42) because the DPI file already exists.
# 	Processing GRB GRB231210B (index 43)...
# Skipping GRB GRB231210B (dpi 43) because the DPI file already exists.
# 	Processing GRB GRB231205B (index 44)...
# Skipping GRB GRB231205B (dpi 44) because the DPI file already exists.
# 	Processing GRB GRB231129A (index 45)...
# Skipping GRB GRB231129A (dpi 45) because the DPI file already exists.
# 	Processing GRB GRB231118A (index 46)...
# Skipping GRB GRB231118A (dpi 46) because the DPI file already exists.
# 	Processing GRB GRB231117A (index 47)...
# Skipping GRB GRB231117A (dpi 47) because the DPI file already exists.
# 	Processing GRB GRB231111A (index 48)...
# Skipping GRB GRB231111A (dpi 48) because the DPI file already exists.
# 	Processing GRB GRB231110A (index 49)...
# Skipping GRB GRB231110A (dpi 49) because the DPI file already exists.
# 	Processing GRB GRB231104A (index 50)...
# Skipping GRB GRB231104A (dpi 50) because the DPI file already exists.
# 	Processing GRB GRB231028A (index 51)...
# Skipping GRB GRB231028A (dpi 51) because the DPI file already exists.
# 	Processing GRB GRB230911C (index 52)...
# Skipping GRB GRB230911C (dpi 52) because the DPI file already exists.
# 	Processing GRB GRB230903A (index 53)...
# Skipping GRB GRB230903A (dpi 53) because the DPI file already exists.
# 	Processing GRB GRB230826A (index 54)...
# Skipping GRB GRB230826A (dpi 54) because the DPI file already exists.
# 	Processing GRB GRB230818A (index 55)...
# Skipping GRB GRB230818A (dpi 55) because the DPI file already exists.
# 	Processing GRB GRB230816A (index 56)...
# Skipping GRB GRB230816A (dpi 56) because the DPI file already exists.
# 	Processing GRB GRB230815A (index 57)...
# Skipping GRB GRB230815A (dpi 57) because the DPI file already exists.
# 	Processing GRB GRB230805B (index 58)...
# Skipping GRB GRB230805B (dpi 58) because the DPI file already exists.
# 	Processing GRB GRB230802A (index 59)...
# Skipping GRB GRB230802A (dpi 59) because the DPI file already exists.
# 	Processing GRB GRB230728A (index 60)...
# Skipping GRB GRB230728A (dpi 60) because the DPI file already exists.
# 	Processing GRB GRB230723B (index 61)...
# Skipping GRB GRB230723B (dpi 61) because the DPI file already exists.
# 	Processing GRB GRB230628E (index 62)...
# Skipping GRB GRB230628E (dpi 62) because the DPI file already exists.
# 	Processing GRB GRB230622A (index 63)...
# Skipping GRB GRB230622A (dpi 63) because the DPI file already exists.
# 	Processing GRB GRB230618A (index 64)...
# Skipping GRB GRB230618A (dpi 64) because the DPI file already exists.
# 	Processing GRB GRB230606A (index 65)...
# Skipping GRB GRB230606A (dpi 65) because the DPI file already exists.
# 	Processing GRB GRB230510A (index 66)...
# Skipping GRB GRB230510A (dpi 66) because the DPI file already exists.
# 	Processing GRB GRB230506C (index 67)...
# Skipping GRB GRB230506C (dpi 67) because the DPI file already exists.
# 	Processing GRB GRB230506B (index 68)...
# Skipping GRB GRB230506B (dpi 68) because the DPI file already exists.
# 	Processing GRB GRB230427A (index 69)...
# Skipping GRB GRB230427A (dpi 69) because the DPI file already exists.
# 	Processing GRB GRB230423A (index 70)...
# Skipping GRB GRB230423A (dpi 70) because the DPI file already exists.
# 	Processing GRB GRB230420A (index 71)...
# Skipping GRB GRB230420A (dpi 71) because the DPI file already exists.
# 	Processing GRB GRB230414B (index 72)...
# Skipping GRB GRB230414B (dpi 72) because the DPI file already exists.
# 	Processing GRB GRB230409B (index 73)...
# Skipping GRB GRB230409B (dpi 73) because the DPI file already exists.
# 	Processing GRB GRB230405B (index 74)...
# Skipping GRB GRB230405B (dpi 74) because the DPI file already exists.
# 	Processing GRB GRB230328B (index 75)...
# Skipping GRB GRB230328B (dpi 75) because the DPI file already exists.
# 	Processing GRB GRB230325A (index 76)...
# Skipping GRB GRB230325A (dpi 76) because the DPI file already exists.
# 	Processing GRB GRB230322B (index 77)...
# Skipping GRB GRB230322B (dpi 77) because the DPI file already exists.
# 	Processing GRB GRB230228A (index 78)...
# Skipping GRB GRB230228A (dpi 78) because the DPI file already exists.
# 	Processing GRB GRB230217A (index 79)...
# Skipping GRB GRB230217A (dpi 79) because the DPI file already exists.
# 	Processing GRB GRB230216A (index 80)...
# Skipping GRB GRB230216A (dpi 80) because the DPI file already exists.
# 	Processing GRB GRB230205A (index 81)...
# Skipping GRB GRB230205A (dpi 81) because the DPI file already exists.
# 	Processing GRB GRB230204A (index 82)...
# Skipping GRB GRB230204A (dpi 82) because the DPI file already exists.
# 	Processing GRB GRB230123A (index 83)...
# Skipping GRB GRB230123A (dpi 83) because the DPI file already exists.
# 	Processing GRB GRB230116D (index 84)...
# Skipping GRB GRB230116D (dpi 84) because the DPI file already exists.
# 	Processing GRB GRB230116C (index 85)...
# Skipping GRB GRB230116C (dpi 85) because the DPI file already exists.
# 	Processing GRB GRB221226B (index 86)...
# Skipping GRB GRB221226B (dpi 86) because the DPI file already exists.
# 	Processing GRB GRB221216A (index 87)...
# Skipping GRB GRB221216A (dpi 87) because the DPI file already exists.
# 	Processing GRB GRB221202A (index 88)...
# Skipping GRB GRB221202A (dpi 88) because the DPI file already exists.
# 	Processing GRB GRB221201A (index 89)...
# Skipping GRB GRB221201A (dpi 89) because the DPI file already exists.
# 	Processing GRB GRB221120A (index 90)...
# Skipping GRB GRB221120A (dpi 90) because the DPI file already exists.
# 	Processing GRB GRB221110A (index 91)...
# Skipping GRB GRB221110A (dpi 91) because the DPI file already exists.
# 	Processing GRB GRB221028A (index 92)...
# Skipping GRB GRB221028A (dpi 92) because the DPI file already exists.
# 	Processing GRB GRB221027B (index 93)...
# Skipping GRB GRB221027B (dpi 93) because the DPI file already exists.
# 	Processing GRB GRB221024A (index 94)...
# Skipping GRB GRB221024A (dpi 94) because the DPI file already exists.
# 	Processing GRB GRB221016A (index 95)...
# Skipping GRB GRB221016A (dpi 95) because the DPI file already exists.
# 	Processing GRB GRB221009A (index 96)...
# Skipping GRB GRB221009A (dpi 96) because the DPI file already exists.
# 	Processing GRB GRB220930A (index 97)...
# Skipping GRB GRB220930A (dpi 97) because the DPI file already exists.
# 	Processing GRB GRB220907A (index 98)...
# Skipping GRB GRB220907A (dpi 98) because the DPI file already exists.
# 	Processing GRB GRB220826A (index 99)...
# Skipping GRB GRB220826A (dpi 99) because the DPI file already exists.
# 	Processing GRB GRB220813A (index 100)...
# Skipping GRB GRB220813A (dpi 100) because the DPI file already exists.
# 	Processing GRB GRB220806A (index 101)...
# Skipping GRB GRB220806A (dpi 101) because the DPI file already exists.
# 	Processing GRB GRB220730A (index 102)...
# Skipping GRB GRB220730A (dpi 102) because the DPI file already exists.
# 	Processing GRB GRB220715B (index 103)...
# Skipping GRB GRB220715B (dpi 103) because the DPI file already exists.
# 	Processing GRB GRB220714B (index 104)...
# Skipping GRB GRB220714B (dpi 104) because the DPI file already exists.
# 	Processing GRB GRB220711B (index 105)...
# Skipping GRB GRB220711B (dpi 105) because the DPI file already exists.
# 	Processing GRB GRB220708A (index 106)...
# Skipping GRB GRB220708A (dpi 106) because the DPI file already exists.
# 	Processing GRB GRB220706A (index 107)...
# Skipping GRB GRB220706A (dpi 107) because the DPI file already exists.
# 	Processing GRB GRB220701A (index 108)...
# Skipping GRB GRB220701A (dpi 108) because the DPI file already exists.
# 	Processing GRB GRB220623A (index 109)...
# Skipping GRB GRB220623A (dpi 109) because the DPI file already exists.
# 	Processing GRB GRB220618A (index 110)...
# Skipping GRB GRB220618A (dpi 110) because the DPI file already exists.
# 	Processing GRB GRB220611A (index 111)...
# Skipping GRB GRB220611A (dpi 111) because the DPI file already exists.
# 	Processing GRB GRB220521A (index 112)...
# Skipping GRB GRB220521A (dpi 112) because the DPI file already exists.
# 	Processing GRB GRB220518A (index 113)...
# Skipping GRB GRB220518A (dpi 113) because the DPI file already exists.
# 	Processing GRB GRB220501A (index 114)...
# Skipping GRB GRB220501A (dpi 114) because the DPI file already exists.
# 	Processing GRB GRB220430A (index 115)...
# Skipping GRB GRB220430A (dpi 115) because the DPI file already exists.
# 	Processing GRB GRB220427A (index 116)...
# Skipping GRB GRB220427A (dpi 116) because the DPI file already exists.
# 	Processing GRB GRB220412B (index 117)...
# Skipping GRB GRB220412B (dpi 117) because the DPI file already exists.
# 	Processing GRB GRB220412A (index 118)...
# Skipping GRB GRB220412A (dpi 118) because the DPI file already exists.
# 	Processing GRB GRB220408A (index 119)...
# Skipping GRB GRB220408A (dpi 119) because the DPI file already exists.
# 	Processing GRB GRB220404A (index 120)...
# Skipping GRB GRB220404A (dpi 120) because the DPI file already exists.
# 	Processing GRB GRB220403B (index 121)...
# Skipping GRB GRB220403B (dpi 121) because the DPI file already exists.
# 	Processing GRB GRB220325A (index 122)...
# Skipping GRB GRB220325A (dpi 122) because the DPI file already exists.
# 	Processing GRB GRB220319A (index 123)...
# Skipping GRB GRB220319A (dpi 123) because the DPI file already exists.
# 	Processing GRB GRB220306B (index 124)...
# Skipping GRB GRB220306B (dpi 124) because the DPI file already exists.
# 	Processing GRB GRB220305A (index 125)...
# Skipping GRB GRB220305A (dpi 125) because the DPI file already exists.
# 	Processing GRB GRB220302A (index 126)...
# Skipping GRB GRB220302A (dpi 126) because the DPI file already exists.
# 	Processing GRB GRB220218A (index 127)...
# Skipping GRB GRB220218A (dpi 127) because the DPI file already exists.
# 	Processing GRB GRB220118A (index 128)...
# Skipping GRB GRB220118A (dpi 128) because the DPI file already exists.
# 	Processing GRB GRB220117B (index 129)...
# Skipping GRB GRB220117B (dpi 129) because the DPI file already exists.
# 	Processing GRB GRB220117A (index 130)...
# Skipping GRB GRB220117A (dpi 130) because the DPI file already exists.
# 	Processing GRB GRB220101A (index 131)...
# Skipping GRB GRB220101A (dpi 131) because the DPI file already exists.
# 	Processing GRB GRB211227A (index 132)...
# Skipping GRB GRB211227A (dpi 132) because the DPI file already exists.
# 	Processing GRB GRB211225B (index 133)...
# Skipping GRB GRB211225B (dpi 133) because the DPI file already exists.
# 	Processing GRB GRB211223C (index 134)...
# Skipping GRB GRB211223C (dpi 134) because the DPI file already exists.
# 	Processing GRB GRB211221A (index 135)...
# Skipping GRB GRB211221A (dpi 135) because the DPI file already exists.
# 	Processing GRB GRB211211A (index 136)...
# Skipping GRB GRB211211A (dpi 136) because the DPI file already exists.
# 	Processing GRB GRB211207A (index 137)...
# Skipping GRB GRB211207A (dpi 137) because the DPI file already exists.
# 	Processing GRB GRB211129A (index 138)...
# Skipping GRB GRB211129A (dpi 138) because the DPI file already exists.
# 	Processing GRB GRB211025A (index 139)...
# Skipping GRB GRB211025A (dpi 139) because the DPI file already exists.
# 	Processing GRB GRB211024B (index 140)...
# Skipping GRB GRB211024B (dpi 140) because the DPI file already exists.
# 	Processing GRB GRB211023B (index 141)...
# Skipping GRB GRB211023B (dpi 141) because the DPI file already exists.
# 	Processing GRB GRB210930A (index 142)...
# Skipping GRB GRB210930A (dpi 142) because the DPI file already exists.
# 	Processing GRB GRB210919A (index 143)...
# Skipping GRB GRB210919A (dpi 143) because the DPI file already exists.
# 	Processing GRB GRB210912A (index 144)...
# Skipping GRB GRB210912A (dpi 144) because the DPI file already exists.
# 	Processing GRB GRB210905A (index 145)...
# Skipping GRB GRB210905A (dpi 145) because the DPI file already exists.
# 	Processing GRB GRB210901A (index 146)...
# Skipping GRB GRB210901A (dpi 146) because the DPI file already exists.
# 	Processing GRB GRB210824A (index 147)...
# Skipping GRB GRB210824A (dpi 147) because the DPI file already exists.
# 	Processing GRB GRB210822A (index 148)...
# Skipping GRB GRB210822A (dpi 148) because the DPI file already exists.
# 	Processing GRB GRB210820A (index 149)...
# Skipping GRB GRB210820A (dpi 149) because the DPI file already exists.
# 	Processing GRB GRB210818A (index 150)...
# Skipping GRB GRB210818A (dpi 150) because the DPI file already exists.
# 	Processing GRB GRB210807C (index 151)...
# Skipping GRB GRB210807C (dpi 151) because the DPI file already exists.
# 	Processing GRB GRB210807A (index 152)...
# Skipping GRB GRB210807A (dpi 152) because the DPI file already exists.
# 	Processing GRB GRB210731A (index 153)...
# Skipping GRB GRB210731A (dpi 153) because the DPI file already exists.
# 	Processing GRB GRB210730A (index 154)...
# Skipping GRB GRB210730A (dpi 154) because the DPI file already exists.
# 	Processing GRB GRB210726A (index 155)...
# Skipping GRB GRB210726A (dpi 155) because the DPI file already exists.
# 	Processing GRB GRB210725B (index 156)...
# Skipping GRB GRB210725B (dpi 156) because the DPI file already exists.
# 	Processing GRB GRB210725A (index 157)...
# Skipping GRB GRB210725A (dpi 157) because the DPI file already exists.
# 	Processing GRB GRB210724A (index 158)...
# Skipping GRB GRB210724A (dpi 158) because the DPI file already exists.
# 	Processing GRB GRB210723A (index 159)...
# Skipping GRB GRB210723A (dpi 159) because the DPI file already exists.
# 	Processing GRB GRB210722A (index 160)...
# Skipping GRB GRB210722A (dpi 160) because the DPI file already exists.
# 	Processing GRB GRB210712A (index 161)...
# Skipping GRB GRB210712A (dpi 161) because the DPI file already exists.
# 	Processing GRB GRB210708A (index 162)...
# Skipping GRB GRB210708A (dpi 162) because the DPI file already exists.
# 	Processing GRB GRB210702A (index 163)...
# Skipping GRB GRB210702A (dpi 163) because the DPI file already exists.
# 	Processing GRB GRB210619B (index 164)...
# Skipping GRB GRB210619B (dpi 164) because the DPI file already exists.
# 	Processing GRB GRB210618A (index 165)...
# Skipping GRB GRB210618A (dpi 165) because the DPI file already exists.
# 	Processing GRB GRB210610B (index 166)...
# Skipping GRB GRB210610B (dpi 166) because the DPI file already exists.
# 	Processing GRB GRB210610A (index 167)...
# Skipping GRB GRB210610A (dpi 167) because the DPI file already exists.
# 	Processing GRB GRB210527A (index 168)...
# Skipping GRB GRB210527A (dpi 168) because the DPI file already exists.
# 	Processing GRB GRB210517A (index 169)...
# Skipping GRB GRB210517A (dpi 169) because the DPI file already exists.
# 	Processing GRB GRB210515C (index 170)...
# Skipping GRB GRB210515C (dpi 170) because the DPI file already exists.
# 	Processing GRB GRB210514A (index 171)...
# Skipping GRB GRB210514A (dpi 171) because the DPI file already exists.
# 	Processing GRB GRB210509A (index 172)...
# Skipping GRB GRB210509A (dpi 172) because the DPI file already exists.
# 	Processing GRB GRB210504A (index 173)...
# Skipping GRB GRB210504A (dpi 173) because the DPI file already exists.
# 	Processing GRB GRB210430A (index 174)...
# Skipping GRB GRB210430A (dpi 174) because the DPI file already exists.
# 	Processing GRB GRB210422A (index 175)...
# Skipping GRB GRB210422A (dpi 175) because the DPI file already exists.
# 	Processing GRB GRB210421A (index 176)...
# Skipping GRB GRB210421A (dpi 176) because the DPI file already exists.
# 	Processing GRB GRB210420B (index 177)...
# Skipping GRB GRB210420B (dpi 177) because the DPI file already exists.
# 	Processing GRB GRB210419C (index 178)...
# Skipping GRB GRB210419C (dpi 178) because the DPI file already exists.
# 	Processing GRB GRB210419A (index 179)...
# Skipping GRB GRB210419A (dpi 179) because the DPI file already exists.
# 	Processing GRB GRB210411C (index 180)...
# Skipping GRB GRB210411C (dpi 180) because the DPI file already exists.
# 	Processing GRB GRB210410A (index 181)...
# Skipping GRB GRB210410A (dpi 181) because the DPI file already exists.
# 	Processing GRB GRB210403A (index 182)...
# Skipping GRB GRB210403A (dpi 182) because the DPI file already exists.
# 	Processing GRB GRB210402A (index 183)...
# Skipping GRB GRB210402A (dpi 183) because the DPI file already exists.
# 	Processing GRB GRB210323A (index 184)...
# Skipping GRB GRB210323A (dpi 184) because the DPI file already exists.
# 	Processing GRB GRB210321A (index 185)...
# Skipping GRB GRB210321A (dpi 185) because the DPI file already exists.
# 	Processing GRB GRB210318A (index 186)...
# Skipping GRB GRB210318A (dpi 186) because the DPI file already exists.
# 	Processing GRB GRB210308A (index 187)...
# Skipping GRB GRB210308A (dpi 187) because the DPI file already exists.
# 	Processing GRB GRB210307A (index 188)...
# Skipping GRB GRB210307A (dpi 188) because the DPI file already exists.
# 	Processing GRB GRB210306B (index 189)...
# Skipping GRB GRB210306B (dpi 189) because the DPI file already exists.
# 	Processing GRB GRB210306A (index 190)...
# Skipping GRB GRB210306A (dpi 190) because the DPI file already exists.
# 	Processing GRB GRB210305A (index 191)...
# Skipping GRB GRB210305A (dpi 191) because the DPI file already exists.
# 	Processing GRB GRB210226A (index 192)...
# Skipping GRB GRB210226A (dpi 192) because the DPI file already exists.
# 	Processing GRB GRB210222B (index 193)...
# Skipping GRB GRB210222B (dpi 193) because the DPI file already exists.
# 	Processing GRB GRB210218A (index 194)...
# Skipping GRB GRB210218A (dpi 194) because the DPI file already exists.
# 	Processing GRB GRB210217A (index 195)...
# Skipping GRB GRB210217A (dpi 195) because the DPI file already exists.
# 	Processing GRB GRB210212A (index 196)...
# Skipping GRB GRB210212A (dpi 196) because the DPI file already exists.
# 	Processing GRB GRB210211A (index 197)...
# Skipping GRB GRB210211A (dpi 197) because the DPI file already exists.
# 	Processing GRB GRB210210A (index 198)...
# Skipping GRB GRB210210A (dpi 198) because the DPI file already exists.
# 	Processing GRB GRB210209A (index 199)...
# Skipping GRB GRB210209A (dpi 199) because the DPI file already exists.
# 	Processing GRB GRB210207B (index 200)...
# Skipping GRB GRB210207B (dpi 200) because the DPI file already exists.
# 	Processing GRB GRB210205A (index 201)...
# Skipping GRB GRB210205A (dpi 201) because the DPI file already exists.
# 	Processing GRB GRB210119A (index 202)...
# Skipping GRB GRB210119A (dpi 202) because the DPI file already exists.
# 	Processing GRB GRB210112A (index 203)...
# Skipping GRB GRB210112A (dpi 203) because the DPI file already exists.
# 	Processing GRB GRB210104B (index 204)...
# Skipping GRB GRB210104B (dpi 204) because the DPI file already exists.
# 	Processing GRB GRB210104A (index 205)...
# Skipping GRB GRB210104A (dpi 205) because the DPI file already exists.
# 	Processing GRB GRB210102C (index 206)...
# Skipping GRB GRB210102C (dpi 206) because the DPI file already exists.
# 	Processing GRB GRB201229A (index 207)...
# Skipping GRB GRB201229A (dpi 207) because the DPI file already exists.
# 	Processing GRB GRB201223A (index 208)...
# Skipping GRB GRB201223A (dpi 208) because the DPI file already exists.
# 	Processing GRB GRB201221D (index 209)...
# Skipping GRB GRB201221D (dpi 209) because the DPI file already exists.
# 	Processing GRB GRB201221A (index 210)...
# Skipping GRB GRB201221A (dpi 210) because the DPI file already exists.
# 	Processing GRB GRB201216C (index 211)...
# Skipping GRB GRB201216C (dpi 211) because the DPI file already exists.
# 	Processing GRB GRB201214B (index 212)...
# Skipping GRB GRB201214B (dpi 212) because the DPI file already exists.
# 	Processing GRB GRB201209A (index 213)...
# Skipping GRB GRB201209A (dpi 213) because the DPI file already exists.
# 	Processing GRB GRB201203A (index 214)...
# Skipping GRB GRB201203A (dpi 214) because the DPI file already exists.
# 	Processing GRB GRB201128A (index 215)...
# Skipping GRB GRB201128A (dpi 215) because the DPI file already exists.
# 	Processing GRB GRB201105A (index 216)...
# Skipping GRB GRB201105A (dpi 216) because the DPI file already exists.
# 	Processing GRB GRB201104B (index 217)...
# Skipping GRB GRB201104B (dpi 217) because the DPI file already exists.
# 	Processing GRB GRB201029A (index 218)...
# Skipping GRB GRB201029A (dpi 218) because the DPI file already exists.
# 	Processing GRB GRB201027A (index 219)...
# Skipping GRB GRB201027A (dpi 219) because the DPI file already exists.
# 	Processing GRB GRB201026A (index 220)...
# Skipping GRB GRB201026A (dpi 220) because the DPI file already exists.
# 	Processing GRB GRB201024A (index 221)...
# Skipping GRB GRB201024A (dpi 221) because the DPI file already exists.
# 	Processing GRB GRB201021C (index 222)...
# Skipping GRB GRB201021C (dpi 222) because the DPI file already exists.
# 	Processing GRB GRB201020A (index 223)...
# Skipping GRB GRB201020A (dpi 223) because the DPI file already exists.
# 	Processing GRB GRB201017A (index 224)...
# Skipping GRB GRB201017A (dpi 224) because the DPI file already exists.
# 	Processing GRB GRB201015A (index 225)...
# Skipping GRB GRB201015A (dpi 225) because the DPI file already exists.
# 	Processing GRB GRB201014A (index 226)...
# Skipping GRB GRB201014A (dpi 226) because the DPI file already exists.
# 	Processing GRB GRB201013A (index 227)...
# Skipping GRB GRB201013A (dpi 227) because the DPI file already exists.
# 	Processing GRB GRB201006A (index 228)...
# Skipping GRB GRB201006A (dpi 228) because the DPI file already exists.
# 	Processing GRB GRB201001A (index 229)...
# Skipping GRB GRB201001A (dpi 229) because the DPI file already exists.
# 	Processing GRB GRB200925B (index 230)...
# Skipping GRB GRB200925B (dpi 230) because the DPI file already exists.
# 	Processing GRB GRB200922A (index 231)...
# Number of events in 64ms window: 1086
# Saved GRBdpi_lowRES/GRBdpi_lowRES_231.npy
# 	Processing GRB GRB200919A (index 232)...
# Number of events in 64ms window: 442
# Saved GRBdpi_lowRES/GRBdpi_lowRES_232.npy
# 	Processing GRB GRB200917A (index 233)...
# Number of events in 64ms window: 599
# Saved GRBdpi_lowRES/GRBdpi_lowRES_233.npy
# 	Processing GRB GRB200909B (index 234)...
# Number of events in 64ms window: 482
# Saved GRBdpi_lowRES/GRBdpi_lowRES_234.npy
# 	Processing GRB GRB200907B (index 235)...
# Number of events in 64ms window: 606
# Saved GRBdpi_lowRES/GRBdpi_lowRES_235.npy
# 	Processing GRB GRB200906A (index 236)...
# Number of events in 64ms window: 562
# Saved GRBdpi_lowRES/GRBdpi_lowRES_236.npy
# 	Processing GRB GRB200903A (index 237)...
# Number of events in 64ms window: 718
# Saved GRBdpi_lowRES/GRBdpi_lowRES_237.npy
# 	Processing GRB GRB200901B (index 238)...
# Number of events in 64ms window: 425
# Saved GRBdpi_lowRES/GRBdpi_lowRES_238.npy
# 	Processing GRB GRB200901A (index 239)...
# Number of events in 64ms window: 578
# Saved GRBdpi_lowRES/GRBdpi_lowRES_239.npy
# 	Processing GRB GRB200829A (index 240)...
# Number of events in 64ms window: 558
# Saved GRBdpi_lowRES/GRBdpi_lowRES_240.npy
# 	Processing GRB GRB200819A (index 241)...
# Number of events in 64ms window: 503
# Saved GRBdpi_lowRES/GRBdpi_lowRES_241.npy
# 	Processing GRB GRB200806A (index 242)...
# Number of events in 64ms window: 850
# Saved GRBdpi_lowRES/GRBdpi_lowRES_242.npy
# 	Processing GRB GRB200729A (index 243)...
# Number of events in 64ms window: 351
# Saved GRBdpi_lowRES/GRBdpi_lowRES_243.npy
# 	Processing GRB GRB200716C (index 244)...
# Number of events in 64ms window: 1984
# Saved GRBdpi_lowRES/GRBdpi_lowRES_244.npy
# 	Processing GRB GRB200713A (index 245)...
# Number of events in 64ms window: 446
# Saved GRBdpi_lowRES/GRBdpi_lowRES_245.npy
# 	Processing GRB GRB200711A (index 246)...
# Number of events in 64ms window: 522
# Saved GRBdpi_lowRES/GRBdpi_lowRES_246.npy
# 	Processing GRB GRB200701A (index 247)...
# Number of events in 64ms window: 450
# Saved GRBdpi_lowRES/GRBdpi_lowRES_247.npy
# 	Processing GRB GRB200630A (index 248)...
# Number of events in 64ms window: 508
# Saved GRBdpi_lowRES/GRBdpi_lowRES_248.npy
# 	Processing GRB GRB200612A (index 249)...
# Number of events in 64ms window: 594
# Saved GRBdpi_lowRES/GRBdpi_lowRES_249.npy
# 	Processing GRB GRB200608A (index 250)...
# Number of events in 64ms window: 509
# Saved GRBdpi_lowRES/GRBdpi_lowRES_250.npy
# Processing complete. 250 GRB dpi files saved.
